# %%
from neo4j import GraphDatabase
import json

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

# Read the credentials from the environment
uri = os.getenv("NEO4J_URI")
username = os.getenv("NEO4J_USER")
password = os.getenv("NEO4J_PASS")

# Check that all values are loaded correctly
assert uri is not None, "NEO4J_URI not found in .env"
assert username is not None, "NEO4J_USER not found in .env"
assert password is not None, "NEO4J_PASS not found in .env"

# Create a connection to Neo4j
driver = GraphDatabase.driver(uri, auth=(username, password))

# Test connection
try:
    with driver.session() as session:
        result = session.run("RETURN 'Connected to Neo4J!' AS message")
        print(result.single()["message"])
except Exception as e:
    print("Connection failed:", e)
finally:
    driver.close()
# Out:
# Connected to Neo4J!

# %%
import json
import os

folder_path = "/Users/wbm/Documents/BIT/Research Topics/few-shot-prompting"

# File paths
file_20_cases = os.path.join(folder_path, "baml_extracted_20_cases.json")
file_remaining = os.path.join(folder_path, "baml_extracted_remaining_cases.json")

# Load both JSON files
with open(file_20_cases, "r") as f:
    data_20_cases = json.load(f)

with open(file_remaining, "r") as f:
    data_remaining_cases = json.load(f)

# Optional: print summary
print(f"Loaded {len(data_20_cases)} cases from 20_cases file.")
print(f"Loaded {len(data_remaining_cases)} cases from remaining_cases file.")
# Out:
# Loaded 20 cases from 20_cases file.
# Loaded 87 cases from remaining_cases file.

# %%
def create_fault_graph(tx, data):
    # 1. Merge FaultLocation and add machine info to a list
    tx.run("""
        MERGE (fl:FaultLocation {name: $loc_name})
        SET fl.machines = apoc.coll.toSet(coalesce(fl.machines, []) + [$machine])
        """,
        loc_name=data["fault_location"]["name"],
        machine=data["fault_location"]["machine"]
    )

    # 2. Create FaultSymptoms and link to FaultLocation
    for symptom in data["fault_symptoms"]:
        tx.run("""
            MERGE (fs:FaultSymptom {description: $symptom})
            WITH fs
            MATCH (fl:FaultLocation {name: $loc_name})
            MERGE (fl)-[:HAS_FAULT]->(fs)
            """,
            symptom=symptom,
            loc_name=data["fault_location"]["name"]
        )

        # 3. Link FaultReasons to FaultSymptom
        for reason in data["fault_reason"]:
            tx.run("""
                MERGE (fr:FaultReason {name: $reason_name})
                WITH fr
                MATCH (fs:FaultSymptom {description: $symptom})
                MERGE (fs)-[:CAUSED_BY]->(fr)
                """,
                reason_name=reason["name"],
                symptom=symptom
            )

        # 4. Link FaultMeasures to FaultSymptom, include resolution status
        for measure in data["fault_measures"]:
            tx.run("""
                MERGE (fm:FaultMeasure {description: $measure_desc})
                WITH fm
                MATCH (fs:FaultSymptom {description: $symptom})
                MERGE (fs)-[r:MITIGATED_BY]->(fm)
                SET r.resolution_status = $status
                """,
                measure_desc=measure["description"],
                symptom=symptom,
                status=data["resolution_status"]
            )

# Run it
with driver.session() as session:
    session.write_transaction(create_fault_graph, data)

driver.close()
# Out:
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_6254/3686131591.py:50: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_6254/3686131591.py:51: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_fault_graph, data)

# %%
from neo4j import GraphDatabase
import json
import os

# -------------------------
# Load the JSON files
# -------------------------
folder_path = "/Users/wbm/Documents/BIT/Research Topics/few-shot-prompting"
file_20_cases = os.path.join(folder_path, "baml_extracted_20_cases.json")
file_remaining = os.path.join(folder_path, "baml_extracted_remaining_cases.json")

with open(file_20_cases, "r") as f:
    data_20_cases = json.load(f)

with open(file_remaining, "r") as f:
    data_remaining_cases = json.load(f)

print(f"Loaded {len(data_20_cases)} cases from 20_cases file.")
print(f"Loaded {len(data_remaining_cases)} cases from remaining_cases file.")

# -------------------------
# Neo4j Connection Setup
# -------------------------
# Load environment variables from .env
load_dotenv()

# Read connection info from environment
uri = os.getenv("NEO4J_URI")
username = os.getenv("NEO4J_USER")
password = os.getenv("NEO4J_PASS")

assert uri, "Missing NEO4J_URI"
assert username, "Missing NEO4J_USER"
assert password, "Missing NEO4J_PASS"

driver = GraphDatabase.driver(uri, auth=(username, password))

# -------------------------
# Define how to create nodes and relationships
# -------------------------
def create_fault_graph(tx, data):
    loc_name = data["fault_location"]["name"]
    machine = data["fault_location"]["machine"]

    if machine:  # Only add machine if it's not None or empty
        tx.run("""
            MERGE (fl:FaultLocation {name: $loc_name})
            SET fl.machines = apoc.coll.toSet(coalesce(fl.machines, []) + [$machine])
            """,
            loc_name=loc_name,
            machine=machine
        )
    else:
        tx.run("""
            MERGE (fl:FaultLocation {name: $loc_name})
            """,
            loc_name=loc_name
        )

    for symptom in data["fault_symptoms"]:
        tx.run("""
            MERGE (fs:FaultSymptom {description: $symptom})
            WITH fs
            MATCH (fl:FaultLocation {name: $loc_name})
            MERGE (fl)-[:HAS_FAULT]->(fs)
            """,
            symptom=symptom,
            loc_name=data["fault_location"]["name"]
        )

        for reason in data["fault_reason"]:
            tx.run("""
                MERGE (fr:FaultReason {name: $reason_name})
                WITH fr
                MATCH (fs:FaultSymptom {description: $symptom})
                MERGE (fs)-[:CAUSED_BY]->(fr)
                """,
                reason_name=reason["name"],
                symptom=symptom
            )

        for measure in data["fault_measures"]:
            tx.run("""
                MERGE (fm:FaultMeasure {description: $measure_desc})
                WITH fm
                MATCH (fs:FaultSymptom {description: $symptom})
                MERGE (fs)-[r:MITIGATED_BY]->(fm)
                SET r.resolution_status = $status
                """,
                measure_desc=measure["description"],
                symptom=symptom,
                status=data["resolution_status"]
            )

# -------------------------
# Push both datasets to Neo4j
# -------------------------
with driver.session() as session:
    for entry in data_20_cases + data_remaining_cases:
        if "result" in entry:
            data = entry["result"]
            session.write_transaction(create_fault_graph, data)
        else:
            print("Skipping entry without 'result':", entry)

driver.close()
print("All data pushed to Neo4j successfully!")
# Out:
# Loaded 20 cases from 20_cases file.
# Loaded 87 cases from remaining_cases file.
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_6254/2080819397.py:94: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_fault_graph, data)
# All data pushed to Neo4j successfully!

# %%
for i, entry in enumerate(data_20_cases + data_remaining_cases):
    if "fault_location" not in entry:
        print(f"Missing 'fault_location' in entry #{i}")
        print(json.dumps(entry, indent=2))
# Out:
# Missing 'fault_location' in entry #0
# {
#   "case_id": "IBM3_C15_23-Feb-15_23-Feb-15",
#   "result": {
#     "fault_location": {
#       "name": "cryocompressor",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "He-verlies/tekort",
#       "Displacer maakt een wat hoog piepend/schrapend geluid"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #1
# {
#   "case_id": "IBM3_C26_21-Sep-16_22-Sep-16",
#   "result": {
#     "fault_location": {
#       "name": "Armkanteling",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Armkanteling werkt niet",
#       "Shutterpositie indicatie: tussenpositie"
#     ],
#     "fault_reason": [
#       {
#         "name": "Shutterpos. In tussen positie is, werkt armkanteling niet"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "JP6 los en pen 2 en 3 aan elkaar gesoldeerd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #2
# {
#   "case_id": "IBM3_C29_05-Jul-17_12-Jul-17",
#   "result": {
#     "fault_location": {
#       "name": "tafel",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "geen positie / rpm detectie",
#       "proces start niet"
#     ],
#     "fault_reason": [
#       {
#         "name": "Lichtsluisje van schijf van / onder tafel deed het niet"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Schoongemaakt. Blauwe draad aangesoldeerd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #3
# {
#   "case_id": "IBM3_C38_18-Nov-19_18-Nov-19",
#   "result": {
#     "fault_location": {
#       "name": "rotatietafel",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Nulpositie vinden lukte niet",
#       "Homing lukt niet"
#     ],
#     "fault_reason": [
#       {
#         "name": "voeding PM150 was uitgezet"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Voeding ibm uit, weer aan"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #4
# {
#   "case_id": "IBM3_C45_26-Oct-20_26-Oct-20",
#   "result": {
#     "fault_location": {
#       "name": "Acc.grid",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "sluiting tegen massa"
#     ],
#     "fault_reason": [
#       {
#         "name": "keramiek van schoefjes die grid-set bij elkaar houden"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "schoefjes vervangen door nieuwe met schone keramiek"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #5
# {
#   "case_id": "IBM3_C46_26-Oct-20_26-Oct-20",
#   "result": {
#     "fault_location": {
#       "name": "Cryopomp",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Uitval cryopomp",
#       "Cryopomp temp. was na afloop: 60K",
#       "IBM4 zakt niet verder dan 150K"
#     ],
#     "fault_reason": [
#       {
#         "name": "koelwater is onvoldoende om beide comperessoren te koelen"
#       }
#     ],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #6
# {
#   "case_id": "IBM3_C4_16-Oct-13_16-Oct-13",
#   "result": {
#     "fault_location": {
#       "name": "Stappenmotor controler",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Arm tilt werkt niet"
#     ],
#     "fault_reason": [
#       {
#         "name": "Stappenmotor controler kreeg geen voeding"
#       },
#       {
#         "name": "Automatische zekering CB4 lag er uit"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Na inschakelen werkte alles weer"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #7
# {
#   "case_id": "IBM3_C53_31-Mar-21_31-Mar-21",
#   "result": {
#     "fault_location": {
#       "name": "Cryopomp",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "storingsmelding tijdens het programma \"pompen\"",
#       "cryopomp nog niet koud",
#       "beeindigd het programma"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "RLY op auto modus gezet"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #8
# {
#   "case_id": "IBM3_C55_10-Aug-21_10-Aug-21",
#   "result": {
#     "fault_location": {
#       "name": "Systeem",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "verliest He-druk",
#       "maakt slepend geluid",
#       "druk: (uit) 192 psi",
#       "druk (koud) 50 psi (piek)"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #9
# {
#   "case_id": "IBM3_C60_29_Mar_22-15-Apr-22",
#   "result": {
#     "fault_location": {
#       "name": "Cryopomp",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "wasmachine geluiden bij afkoelen",
#       "Regeneratie ging probleemloos / < 60K wasmachine geluiden"
#     ],
#     "fault_reason": [
#       {
#         "name": "Zeer waarschijnlijk is de cryopomp verontreinigd"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Absorber is vervangen"
#       },
#       {
#         "description": "Het complete systeem is gespoeld met helium volgens procedure"
#       },
#       {
#         "description": "De machine laten regenereren en afkoelen tot 17 K"
#       },
#       {
#         "description": "Aluminium reflector in de IBM 3 geplaatst om enkele testruns te draaien"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #10
# {
#   "case_id": "IBM3_C74_12-Sep-23_12-Sep-23",
#   "result": {
#     "fault_location": {
#       "name": "Neutralizer",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "IBM3 start niet door / blijft hangen",
#       "emissie: 23mA",
#       "blijkt hangen op status 'plasma'",
#       "blijkt hangen op status 'neutralizer check'"
#     ],
#     "fault_reason": [
#       {
#         "name": "kathode en binnenwerk: als nieuw / poeder op bodem / diafragma & huis geoxideerd"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "gemicroblast (nog niet getest)"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #11
# {
#   "case_id": "IBM3_C9_28-Jul-14_28-Jul-14",
#   "result": {
#     "fault_location": {
#       "name": "Shutterindicator",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "foutmelding in scherm"
#     ],
#     "fault_reason": [
#       {
#         "name": "kabeltje nr.17 die naar de shutter-module gaat"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Niet verbinden / kabeltje 17 losgesoldeerd en geisoleerd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #12
# {
#   "case_id": "IBM4_C31_27-Mar-17_27-Mar-17",
#   "result": {
#     "fault_location": {
#       "name": "accelerator board",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Geen Uacc"
#     ],
#     "fault_reason": [
#       {
#         "name": "Zekering op accelerator board kapot"
#       }
#     ],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #13
# {
#   "case_id": "IBM4_C37_25-Jun-18_25-Jun-18",
#   "result": {
#     "fault_location": {
#       "name": "Koelwaterslang bij compressor",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Veel water op de vloer"
#     ],
#     "fault_reason": [
#       {
#         "name": "Slang waarschijnlijk kapot gegaan door sterke insnoering op swagelok koppeling"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Beide slangen (groen), vervangen en op compressor aangesloten door conusvorm in slang te drukken"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #14
# {
#   "case_id": "IBM4_C59_05-Aug-21_05-Aug-21",
#   "result": {
#     "fault_location": {
#       "name": "Compressor",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Tijdens regenereren valt de compressor uit",
#       "inlaat temp. 34 graden celcius",
#       "uitgangs temp. ruim onder 20 graden celcius"
#     ],
#     "fault_reason": [
#       {
#         "name": "probleem met de koeling"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Koelslangen omgewisseld en de compressor werkt weer"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #15
# {
#   "case_id": "IBM4_C62_23-Dec-21_23-Dec-21",
#   "result": {
#     "fault_location": {
#       "name": "neutralizer",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "emissie was maar 5 mA",
#       "sluiting in accellerator grid I-acc = 100 - 200mA"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "settings / cal.factor => was 10 mA / nu ingesteld op 2 mA"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #16
# {
#   "case_id": "IBM4_C74_01-Dec-22_01-Dec-22",
#   "result": {
#     "fault_location": {
#       "name": "PLC kaart",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Storing communicatie ARC-net",
#       "PC is traag, reageert slecht",
#       "varierende waterdruk",
#       "compressor had moeite met hoog vacuum",
#       "Waterdruk pendelde tussen 8 en 10 liter per minuut"
#     ],
#     "fault_reason": [
#       {
#         "name": "PC is traag, reageert slecht ongeveer gelijk aan de storing van 03 okt. Jl"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "noodstop ingedrukt zodat het cryo gedeelte bleef pompen en daarna de kaarten van de PLC gecontroleerd, PLC kaart CPU BRARCIF-0T uitgewisseld met de kaart uit IBM 3 en alles opnieuw gesynchroniseerd"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #17
# {
#   "case_id": "IBM4_C77_18-Mar-23_19-Apr-23",
#   "result": {
#     "fault_location": {
#       "name": "Rotatie tafel",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Rotatie tafel blijft draaien",
#       "sensor lijkt niet te werken",
#       "Sensor ziet er slecht uit"
#     ],
#     "fault_reason": [
#       {
#         "name": "2 draden los, 1 weerstand doorgebrand"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "9 polige sub-D connector rechts boven in machine: vervangen / nieuwe bedrading"
#       },
#       {
#         "description": "Weerstanden vervangen(pen 4 en pen 5): 330 \u03a9"
#       },
#       {
#         "description": "opto (OPB365T55) vervangen en een nieuwe kabel gemonteerd in bak van de arm"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #18
# {
#   "case_id": "IBM4_C79_13-Jun-23_13-Jun-23",
#   "result": {
#     "fault_location": {
#       "name": "HV-klep",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Opstartproblemen",
#       "Voorpomp stuiterde"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #19
# {
#   "case_id": "IBM4_C91_23-Sept-24_01-Oct-24",
#   "result": {
#     "fault_location": {
#       "name": "glycolpomp",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Stekker maakt sluiting",
#       "bijna doorgebrand"
#     ],
#     "fault_reason": [
#       {
#         "name": "Stekker glycolpomp maakt sluiting"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Spanning van machine gehaald, bij Reichelt nieuwe Hirschmann stak 3 en stasei 3 connectoren besteld"
#       },
#       {
#         "description": "Nieuwe connectoren geplaast, kabel ingekort was doorgebrand, alles vernieuwd incl. adereind hulzen"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #20
# {
#   "case_id": "IBM3_C14_15-Jan-15_15-Jan-15",
#   "result": {
#     "fault_location": {
#       "name": "Bron",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Bron startte niet door",
#       "emissie blijft vaak beperkt tot 24mA",
#       "oude probleem, geen bundel uit de bron"
#     ],
#     "fault_reason": [
#       {
#         "name": "Anode bleek een dikke harde isolerende laag te hebben"
#       },
#       {
#         "name": "Kwartscilinder was niet vervangen en had bij anode veel coating"
#       },
#       {
#         "name": "Er is een kans, dat daardoor via de afscherming de anode verbonden wordt met het binnenste grid"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Anode schoongeschuurd"
#       },
#       {
#         "description": "Schone kwartscilinder er in"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #21
# {
#   "case_id": "IBM3_C15_25-Mar-15_25-Mar-15",
#   "result": {
#     "fault_location": {
#       "name": "cryocompressor",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "He bijgevuld van cryocompressor (Was 4 bar, nu 15,5bar)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #22
# {
#   "case_id": "IBM3_C19_02-Jul-15_05-Nov-15",
#   "result": {
#     "fault_location": {
#       "name": "Compressor",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Lekkage gevonden bij adsorber aansluiting",
#       "He-lekkage aan de heatexchanger",
#       "Druk direct na aanzetten: 5,4 bar",
#       "Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo"
#     ],
#     "fault_reason": [
#       {
#         "name": "Lekkage bij adsorber aansluiting"
#       },
#       {
#         "name": "He-lekkage aan de heatexchanger"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)"
#       },
#       {
#         "description": "Compressor afgevuld op 265 psi"
#       },
#       {
#         "description": "Compressor naar VS: warmte wisselaar vervangen"
#       },
#       {
#         "description": "Alle kleppen, heatexchanger, condensator wordt vervangen"
#       },
#       {
#         "description": "Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #23
# {
#   "case_id": "IBM3_C20_18-Jan-16_18-Jan-16",
#   "result": {
#     "fault_location": {
#       "name": "Ionbeam-controller",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Neutralizer wilde niet starten",
#       "Te weinig spanning op het scherm (37V)"
#     ],
#     "fault_reason": [
#       {
#         "name": "Relais van print kan ratelen als Glasmann voeding geen 220V heeft"
#       },
#       {
#         "name": "Er komt pas spanning van Glasmann voeding, als deze vrijgegeven wordt door de ibm controller"
#       },
#       {
#         "name": "Dit gebeurt pas, als de neutralizer wordt gestart nadat het Ar in de neutralizer stroomt"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Kabel naar print getest. Ok"
#       },
#       {
#         "description": "Glasmann voedingen getest; nieuw = 1001V / oud = 996V"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #24
# {
#   "case_id": "IBM3_C25_20-Sep-16_20-Sep-16",
#   "result": {
#     "fault_location": {
#       "name": "Tafelrotatie",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Print met contactsporen was niet goed",
#       "Buitenste spoor deels weg",
#       "Draden snelheidsmeting naar sensor 1x geen goede verbinding"
#     ],
#     "fault_reason": [
#       {
#         "name": "Print met contactsporen was niet goed"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Schoongemaakt, pennen opnieuw vastgesoldeerd"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #25
# {
#   "case_id": "IBM3_C27_27-Sep-16_24-Nov-16",
#   "result": {
#     "fault_location": {
#       "name": "Keypad",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Keypad kapot",
#       "geen communicatie met module in/bij cryopomp"
#     ],
#     "fault_reason": [
#       {
#         "name": "kortsluiting voeding"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Opnieuw geprogrammeerde keypad weer teruggezet in ibm3"
#       },
#       {
#         "description": "Controller van cryo uit ibm4 voorzien van aangepaste info en in ibm3 gezet"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #26
# {
#   "case_id": "IBM3_C32_26-Jun-19_26-Jun-19",
#   "result": {
#     "fault_location": {
#       "name": "MFC-kanaal1 / neutralizer",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Blijft soms hangen",
#       "phaco in eens naar 63 sccm",
#       "Proces erop uitgevallen"
#     ],
#     "fault_reason": [
#       {
#         "name": "in werkelijk werd de MFC van de bron aangestuurd"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Test: stekkers op MFC's omgedraaid. Probleem bleef op zelfde plek in beeldscherm (neutralizer) optreden"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #27
# {
#   "case_id": "IBM3_C35_06-Aug-19_06-Aug-19",
#   "result": {
#     "fault_location": {
#       "name": "communication system",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Problemen met communicatie tussen computer en IBM3"
#     ],
#     "fault_reason": [
#       {
#         "name": "Het zat niet in de kabeltjes of gammele RJ12 stekker"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Computer opnieuw opgestart. Toen werd blijkbaar wel de kaart herkend."
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #28
# {
#   "case_id": "IBM3_C37_30-Sep-19_30-Sep-19",
#   "result": {
#     "fault_location": {
#       "name": "Interlock schakelaar voordeur",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Kapot"
#     ],
#     "fault_reason": [
#       {
#         "name": "oude versie niet te bestellen"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Nieuwe besteld en gemonteerd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #29
# {
#   "case_id": "IBM3_C39_12-Mar-20_24-Mar-20",
#   "result": {
#     "fault_location": {
#       "name": "voorpomp",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "pomp kun je wel aan te zetten. Blijft (enige tijd) draaien, als je deze uitzet"
#     ],
#     "fault_reason": [
#       {
#         "name": "roterende asdoorvoer vervangen. (Was kapot)"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Viton pakking gesneden en de roterende asdoorvoer vervangen"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #30
# {
#   "case_id": "IBM3_C48_11-Jan-21_11-Jan-21",
#   "result": {
#     "fault_location": {
#       "name": "automatische zekering / schakelaar",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Inschakelen werkt niet",
#       "Je hoort niets schakelen",
#       "geen 3 fasen op andere relais",
#       "Geen 15V/24V op uitgang"
#     ],
#     "fault_reason": [
#       {
#         "name": "voeding niet goed"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Nieuwe automatische zekering / schakelaar erin (rechter box / helemaal links-boven)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #31
# {
#   "case_id": "IBM3_C49_09-Mar-21_09-Mar-21",
#   "result": {
#     "fault_location": {
#       "name": "Keypad",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "geheugen kwijt",
#       "houdt nieuwe data niet vast",
#       "Niet in automode te zetten (relais 1 en 2)"
#     ],
#     "fault_reason": [
#       {
#         "name": "Lijkt erop dat keypad de data ergens ophaald"
#       }
#     ],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #32
# {
#   "case_id": "IBM3_C50_19-Mar-21_19-Mar-21",
#   "result": {
#     "fault_location": {
#       "name": "Multiple components",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "IBM 3 nadien niet meer functioneel",
#       "linkse 3 voudige automaat functioneerde niet meer",
#       "Keypad cryopomp geeft storing aan",
#       "module van de cryopomp houdt het geheugen niet vast",
#       "Probleem met hardeschijf PC",
#       "ARC net valt uit",
#       "Rotatie tafel werkt niet",
#       "Voeding stappenmotor valt spontaan uit",
#       "Automaat voeding stappenmotor valt uit",
#       "Schutter werkt niet",
#       "Storing waterlekkage"
#     ],
#     "fault_reason": [
#       {
#         "name": "weerstand in kabel doorgebrand"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "linkse 3 voudige automaat vervangen door een nieuwe"
#       },
#       {
#         "description": "24 volt voeding Protek opgestuurd voor reparatie"
#       },
#       {
#         "description": "module van de cryopomp opgestuurd"
#       },
#       {
#         "description": "weerstand vervangen door een 1K5 (5W) weerstand"
#       },
#       {
#         "description": "reed contacten hersteld en de overbrugging weggehaald"
#       },
#       {
#         "description": "Rotatie tafel opnieuw afgesteld doormiddel van de steun op de as te verplaatsen"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #33
# {
#   "case_id": "IBM3_C52_30-Mar-21_30-Mar-21",
#   "result": {
#     "fault_location": {
#       "name": "Cryopomp",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [],
#     "fault_reason": [
#       {
#         "name": "module stond nog in de basis instellingen"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Arc-net kaart vervangen door een nieuwe kaart"
#       },
#       {
#         "description": "RLY2 instellingen aangepast van Off,manual naar Off,auto"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #34
# {
#   "case_id": "IBM3_C59_08-Dec-21_24-Feb-22",
#   "result": {
#     "fault_location": {
#       "name": "Compressor",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "He-lekkage in compressor"
#     ],
#     "fault_reason": [
#       {
#         "name": "naaldafsluiter niet naar behoren werkt"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Hulpstuk gemaakt om de naaldafsluiter te testen op lekkage, naaldafsluiter wat harder aangedraait"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #35
# {
#   "case_id": "IBM3_C61_26-Apr-22_26-Apr-22",
#   "result": {
#     "fault_location": {
#       "name": "Etsprogramma",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Etsprogramma start niet door",
#       "Lijkt vaker op te treden als bron / machine warm is"
#     ],
#     "fault_reason": [
#       {
#         "name": "oorzaak onbekend"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "deels vullen met N2 / > 1uur laten afkoelen"
#       },
#       {
#         "description": "uitproberen: P-start. bron verlagen (350W ?) (zie settings / Etch plasma start) Init. Accel voltage verhogen / verlagen. Init. beam voltage verhogen"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #36
# {
#   "case_id": "IBM3_C62_5-May-22_6-May-22",
#   "result": {
#     "fault_location": {
#       "name": "Etsprogramma",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Etsprogramma start niet altijd door",
#       "opstartproblemen met programma InfGen4",
#       "machine start niet door na enkele malen opnieuw starten"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #37
# {
#   "case_id": "IBM3_C64_09-Aug-22_09-Aug-22",
#   "result": {
#     "fault_location": {
#       "name": "bron",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "start in stand \"plasma\" niet door"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #38
# {
#   "case_id": "IBM3_C65_15-Aug-22_25-Aug-22",
#   "result": {
#     "fault_location": {
#       "name": "Roterende doorvoer van de tafel",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "druk 3 * 10-5 (HV klep open)",
#       "druktoename in 24 min",
#       "druk varieert was 0.06 mbar / wordt 0.8 mbar",
#       "tafel rot. 2.0 oplopend naar 0.8 mbar in 5 min"
#     ],
#     "fault_reason": [
#       {
#         "name": "Roterende doorvoer van de tafel is niet goed"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "tafel opnieuw getest"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #39
# {
#   "case_id": "IBM3_C66_09-Sep-22_13-Sep-22",
#   "result": {
#     "fault_location": {
#       "name": "Iongauge",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Glycol koeling op tafelas lekte",
#       "Iongauge IBM3 bleek kapot",
#       "Uitlezing wat te laag",
#       "Ibm3 werkt. Start soms niet door"
#     ],
#     "fault_reason": [
#       {
#         "name": "onderste seal lekte / was beschadigd"
#       },
#       {
#         "name": "Beide filamenten kapot"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Ring 1/2 uur in oven op 90 deg.C. / vouw met pincet er uit gedrukt"
#       },
#       {
#         "description": "Iongauge van IBM4 in IBM3 gezet"
#       },
#       {
#         "description": "Oude reserve Edwards iongauge gemonteerd op ibm3"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #40
# {
#   "case_id": "IBM3_C68_21-Sep-22_29-Sep-22",
#   "result": {
#     "fault_location": {
#       "name": "On-Board module / CTI 9600",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Waterschade ibm3",
#       "zwaar beschadigd printen",
#       "SKT1 zwaar gecorrodeerd",
#       "problemen met hoofdprint"
#     ],
#     "fault_reason": [
#       {
#         "name": "gecorrodeerde flowmeter"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Voorlopig geparkeerd, spullen terug in ibm4"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #41
# {
#   "case_id": "IBM3_C69_28-Feb-23_28-Feb-23",
#   "result": {
#     "fault_location": {
#       "name": "N-module (cryo onboard module)",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "voorpomp wordt niet gestart bij regeneratie"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "voorpomp handmatig aanzetten"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #42
# {
#   "case_id": "IBM3_C70_14-Mar-23_14-Mar-23",
#   "result": {
#     "fault_location": {
#       "name": "Synchronatie arm (sub.tafel)",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "werkt niet / rotatie wel",
#       "stopt niet op de optische sensor",
#       "draait om na het bereiken van de micro-switch"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #43
# {
#   "case_id": "IBM3_C71_16-Mar-23_23-Mar-23",
#   "result": {
#     "fault_location": {
#       "name": "Iongauge",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "drukttoename / gelijk uit op interlock fout",
#       "blauwe draden van 26B en 26D niet verbonden met de pinnen van P1"
#     ],
#     "fault_reason": [
#       {
#         "name": "blauwe draden van 26B en 26D niet verbonden met de pinnen van P1"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Doorverbindingen op moederboard gemaakt (via draad-hup)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #44
# {
#   "case_id": "IBM3_C72_23-Mar-23_23-Mar-23",
#   "result": {
#     "fault_location": {
#       "name": "Tafel",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Synchroniseren lukte niet",
#       "arm keerde voortijdig om van richting (zonder optische sensor of eindschakelaar)"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Kamer beluchten en open en gelijk weer dicht, om te kunnen synchroniseren. Machine hoeft niet uit"
#       },
#       {
#         "description": "Instellen op: 90 / kies \"home\" in bovenste vakje | Op pijltje klikken (arm stopt helemaal bovenin (bij bron) | Dan: op -90 zetten / klik op pijltje (arm gaat weer terug naar horizontale (laad)positie.)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #45
# {
#   "case_id": "IBM3_C73_19-Apr-23_19-Apr-23",
#   "result": {
#     "fault_location": {
#       "name": "pomp glycol unit",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [],
#     "fault_reason": [
#       {
#         "name": "doorgebrand"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "reserve gemonteerd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #46
# {
#   "case_id": "IBM3_C74_23-Oct-23_23-Oct-23",
#   "result": {
#     "fault_location": {
#       "name": "Bron",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Bron schoongemaakt"
#       },
#       {
#         "description": "grid schoongemaakt met zoutzuur"
#       },
#       {
#         "description": "kwarts cilinder vervangen door een schone / gebruikte"
#       },
#       {
#         "description": "anode plaat eruit en gestraald"
#       },
#       {
#         "description": "dekplaat bron gestraald"
#       },
#       {
#         "description": "schroeven voor aandrukken ring van kwartscilinder vervangen door inbus"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #47
# {
#   "case_id": "IBM3_C76_29-Jan-24_1-Feb-24",
#   "result": {
#     "fault_location": {
#       "name": "Rotatie platen drive",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Rotatie platen drive werkt niet",
#       "timing belt beschadigd",
#       "lekkage van het glycol koelwater",
#       "tandriem versleten",
#       "tanden verdwenen"
#     ],
#     "fault_reason": [
#       {
#         "name": "timing belt beschadigd (mist wat tanden)"
#       },
#       {
#         "name": "lekkage van het glycol koelwater"
#       },
#       {
#         "name": "tandriem versleten"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Tandriemen besteld bij Eriks, 6t5-305, 6t5-330"
#       },
#       {
#         "description": "De bestelde tandriemen zijn binnen gekomen, het blijkt de 6T5-330 te zijn ipv. de 305"
#       },
#       {
#         "description": "Deze is gemonteerd en er wordt een lektest gedaan op het glycol systeem in de rotatiearm vacuum bak"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #48
# {
#   "case_id": "IBM3_C77_31-Jan-24_31-Jan-24",
#   "result": {
#     "fault_location": {
#       "name": "arc net",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Spanningsdip geweest"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "machine moet opnieuw ingeregeld worden"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #49
# {
#   "case_id": "IBM3_C79_15-Apr-24_15-Apr-24",
#   "result": {
#     "fault_location": {
#       "name": "Rotatie arm",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "werkt niet"
#     ],
#     "fault_reason": [
#       {
#         "name": "as zat vast"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "tandriem opnieuw gespannen en test gedraaid"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #50
# {
#   "case_id": "IBM3_C80_16-Apr-24_16-Apr-24",
#   "result": {
#     "fault_location": {
#       "name": "PC",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "PC traag en reageert niet",
#       "foutmelding in het beeldscherm"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "machine en PC opnieuw opgestart"
#       },
#       {
#         "description": "Machine nogmaals opnieuw opgestart"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #51
# {
#   "case_id": "IBM3_C81_22-May-24_22-May-24",
#   "result": {
#     "fault_location": {
#       "name": "Machine",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Pc vastgelopen",
#       "Fil1 en Fil2 ramp werkt niet",
#       "filamenten blijven oplichten zonder actief programma",
#       "filamenten lichten op zonder programma (in vacuum)"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Pc opnieuw opgestart"
#       },
#       {
#         "description": "Machine en Pc opnieuw opgestart"
#       },
#       {
#         "description": "PLC 3 naar IBM4 verplaatst voor test"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #52
# {
#   "case_id": "IBM3_C82_06-Jun-24_06-Jun-24",
#   "result": {
#     "fault_location": {
#       "name": "Target",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "status fault",
#       "start niet door"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #53
# {
#   "case_id": "IBM3_C83_21-Jun-24_21-Jun-24",
#   "result": {
#     "fault_location": {
#       "name": "PLC",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "PLC start op in draft versie versie 300,184 - not for release",
#       "storing treed op als de ARC-net kaart PO6457 gemonteerd is in PLC 2",
#       "De andere nieuwe ARC-net kaart (PO6404) geeft de storing \u2206 op Etch source",
#       "Voeding stappenmotor uitgevallen"
#     ],
#     "fault_reason": [
#       {
#         "name": "ARC-net kaart PO6457 (nieuw herstelde) gemonteerd in PLC 2"
#       },
#       {
#         "name": "De andere nieuwe ARC-net kaart (PO6404) geeft de storing \u2206 op Etch source"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Mail naar Steffan van besturingen .com gestuurd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #54
# {
#   "case_id": "IBM3_C84_24-Jun-24_24-Jun-24",
#   "result": {
#     "fault_location": {
#       "name": "ARC-Net kaart",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "kaarten zouden gewoon moeten werken op elke PLC wat niet het geval is"
#     ],
#     "fault_reason": [
#       {
#         "name": "issues waar ik tegenaan loop kan hij ook niet verklaren"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "adviseerd om toch nog een ARC-Net kaart te kopen omdat deze zo goed als niet meer leverbaar zijn"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #55
# {
#   "case_id": "IBM3_C85_27-Jun-24_27-Jun-24",
#   "result": {
#     "fault_location": {
#       "name": "Pc",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Pc traag",
#       "harde schijf continu in bedrijf zonder een lopend programma op de achtergrond"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #56
# {
#   "case_id": "IBM3_C86_28-Jun-24_28-Jun-24",
#   "result": {
#     "fault_location": {
#       "name": "Pc",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "reageert nergens op",
#       "compleet vastgelopen"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "opnieuw op te starten"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #57
# {
#   "case_id": "IBM3_C87_03-Jul-24_03-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Cryopomp",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Cryopomp maakt \"kloppende\" geluiden bij 30K/17K regeneratie",
#       "Koelen gaat erg traag van 30K tot klaar voor gebruik"
#     ],
#     "fault_reason": [
#       {
#         "name": "waarschijnlijk is de cryopomp verontreinigd"
#       }
#     ],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #58
# {
#   "case_id": "IBM3_C88_03-Jul-24_03-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Pc",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "reageert weer niet"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #59
# {
#   "case_id": "IBM3_C89_04-Jul-24_04-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Filamenten",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Filamenten starten niet op"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "eerst plaat verwijderen of deze nog functioneren of dat het probleem elders zit"
#       },
#       {
#         "description": "verder de originele controller terug geplaatst"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #60
# {
#   "case_id": "IBM3_C90_04-Jul-24_04-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Cryopomp",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Cryopomp gaat van 13K naar 22K",
#       "lopende programma wordt afgebroken tot deze weer op temp is"
#     ],
#     "fault_reason": [
#       {
#         "name": "waarschijnlijk adsorber vervangen, het systeem lijkt verontreinigd"
#       }
#     ],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #61
# {
#   "case_id": "IBM3_C91_08-Jul-24_08-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Filamenten",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "filamenten lichten op, echter duurt het lang voordat Fil1 de actuele waarde geeft"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "volledige regeneratie met de cryopomp"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #62
# {
#   "case_id": "IBM3_C92_25-Jul-24_25-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "filamenten",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "filamenten starten traag",
#       "soms duurt dit enkele minuten"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "spanning van de controller (rechter potmeter) iets verhoogd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #63
# {
#   "case_id": "IBM3_C93_26-Jul-24_26-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "arm cover",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Lekkage glycol in de cover van de arm"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Bestellen van keerringen en O-ringen via Oxford (ger-pt-office@oxinst.com)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #64
# {
#   "case_id": "IBM3_C94_30-Jul-24_30-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Pc",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "nieuwe opstart ging deze kapot"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Nieuwe Pc geplaatst"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #65
# {
#   "case_id": "IBM3_C95_18-Sep-24_18-Sep-24",
#   "result": {
#     "fault_location": {
#       "name": "software",
#       "machine": "IBM3"
#     },
#     "fault_symptoms": [
#       "Enkele software problemen bij het programma pompen, pomp tijd en de Ion gauge"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "De machine kan bediend worden in een andere modus. In engineerings mode de manuele stand gebruiken met een uitgeschakelde Ion gauge. Er staat een digitale uitlezing bij met een aangesloten PKR 251 die de juiste uitlezing van het vacuum geeft, terug pompen tot minimaal 1x 10-5. Daarna het programma starten, bijv. infgen4."
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #66
# {
#   "case_id": "IBM4_C14_16-Jul-14_21-Jul-14",
#   "result": {
#     "fault_location": {
#       "name": "Neutralizer",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Gasflowregeling (Ar) werkte soms in servicemode, niet in usermode",
#       "Neutralizer start niet goed op",
#       "Ontladingsstroom is te klein (3-50mA)",
#       "Interlock fout in servicemode",
#       "Al-oxide buis steekt iets uit",
#       "Output spanning voor de discharge in de neutralizer zakt (350 \u2013 280V)",
#       "Stroom door de ontlading onstabiel en onvoldoende (0 \u2013 50 mA bij 20 sccm)"
#     ],
#     "fault_reason": [
#       {
#         "name": "Inlaatgasklep blijft waarschijnlijk dichtzitten"
#       },
#       {
#         "name": "Gebroken al-oxide plaat in neutralizer"
#       },
#       {
#         "name": "Voedings-unit (deels) defect"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Hele gas-unit (twee kleppen met massaflowmeter uit ibm3 in ibm4 gezet)"
#       },
#       {
#         "description": "Al-oxide schijf vernieuwd"
#       },
#       {
#         "description": "Ion source controller isc 600 vervangen (komt uit ibm3)"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #67
# {
#   "case_id": "IBM4_C15_11-Sept-14_11-Sept-14",
#   "result": {
#     "fault_location": {
#       "name": "Spanning bron",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Spanning bron komt niet in",
#       "soms heel kort (<1sec) 350V zichtbaar"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Buitenkant kap van bron verwijdert, linker dekplaatjes van bron geschroeft"
#       },
#       {
#         "description": "Aan schuitingen A en C los en gecontroleerd door multimeter in serie met 220V AC te meten"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #68
# {
#   "case_id": "IBM4_C16_20-Nov-14_20-Nov-14",
#   "result": {
#     "fault_location": {
#       "name": "Neutralizer",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Geen emissie met nieuw diafragma",
#       "Emissie: <1mA"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Oude diafragma weer erin gezet (diam. gat 1,3mm)"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #69
# {
#   "case_id": "IBM4_C19_05-Feb-15_05-Feb-15",
#   "result": {
#     "fault_location": {
#       "name": "Generator",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "generator niet het volle vermogen haalt",
#       "systeem niet verder gaat als de generator geen 500W haalt",
#       "neutralizer wel 300mA als ontlading geeft maar (bijna) geen emissie",
#       "ontlading niet stabiel brandt in de neutralizer",
#       "isolatoren vervuild",
#       "kathode niet goed meer",
#       "gat in diagragma te groot (drukverlies in de neutralizer)",
#       "oxides op diafragma aan binnenkant",
#       "O-ring bij deur weg (onvoldoende gas in neutralizer (of bron))"
#     ],
#     "fault_reason": [
#       {
#         "name": "generator niet het volle vermogen haalt"
#       },
#       {
#         "name": "ontlading niet stabiel brandt in de neutralizer"
#       },
#       {
#         "name": "isolatoren vervuild"
#       },
#       {
#         "name": "kathode niet goed meer"
#       },
#       {
#         "name": "gat in diagragma te groot (drukverlies in de neutralizer)"
#       },
#       {
#         "name": "oxides op diafragma aan binnenkant"
#       },
#       {
#         "name": "O-ring bij deur weg (onvoldoende gas in neutralizer (of bron))"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Kapotte generator vervangen door reserve generator"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #70
# {
#   "case_id": "IBM4_C1_09-Aug-10_09-Aug-10",
#   "result": {
#     "fault_location": {
#       "name": "Arm",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Homing van arm-tilt werkt niet",
#       "geen groen rondje op beeldscherm te zien",
#       "Status is moving"
#     ],
#     "fault_reason": [
#       {
#         "name": "Platen shutter positie stond in een tussen positie"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Met tang de as van de shutter in een uiterste positie gezet"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #71
# {
#   "case_id": "IBM4_C20_10-Mar-15_10-Mar-15",
#   "result": {
#     "fault_location": {
#       "name": "Neutralizer",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "geen emissie (3 mA)",
#       "geen testspanning zichtbaar"
#     ],
#     "fault_reason": [
#       {
#         "name": "Blisters voor neutralizer opening, mogelijk blisters die sluiting tussen buitenste grid en aarde gaven"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "grid schoongemaakt, anode gestraald (was paars/groen)"
#       },
#       {
#         "description": "Neutralizer behuizing/binnenkant gestraald en diafragma plaatje met lage druk voorzichtig gestraald (om oxides te verwijderen)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #72
# {
#   "case_id": "IBM4_C22_02-Jun-15_12-Jun-15",
#   "result": {
#     "fault_location": {
#       "name": "RF-generator",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Stank",
#       "Sterke pertinax lucht",
#       "Plasma bron starte niet op",
#       "HV-drukuitlezing het niet",
#       "Bron/plasma was na 5,5 uur Phaco etsen uitgevallen",
#       "Testspanningen (400V bron / 99V excel.) waren heel kort zichtbaar",
#       "Anode plaat in bron sterk geoxideerd",
#       "Defecte RF-generator and ibm-controler"
#     ],
#     "fault_reason": [
#       {
#         "name": "doorgebrandde bekabeling/print van voeding van RF-generator"
#       },
#       {
#         "name": "kapotte RF voeding"
#       },
#       {
#         "name": "RF-communication board broke down"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "stekker nadrukken en probleem was verholpen"
#       },
#       {
#         "description": "Anode plaat gestraald, met iso schoongemaakt en gemonteerd"
#       },
#       {
#         "description": "Eerder gerepareerde reserve generator die geplaatst is"
#       },
#       {
#         "description": "We changed the RF-generator"
#       },
#       {
#         "description": "After mounting an other ionbeam controller, this problem was solved"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #73
# {
#   "case_id": "IBM4_C23_08-Jun-15_09-Jun-15",
#   "result": {
#     "fault_location": {
#       "name": "Grid",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Beam valt uit (out of tollerance)",
#       "Bij 135 mA viel bundel en plasma uit",
#       "Bundel valt uit onder de 150mA",
#       "Bundel valt uit onder de 170mA"
#     ],
#     "fault_reason": [
#       {
#         "name": "Probleem met 1,00mm gridset"
#       },
#       {
#         "name": "Probleem met 1,30mm gridset"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Kwarts cilinder in de bron vervangen voor een schone"
#       },
#       {
#         "description": "Grid uit ibm3 in ibm4 gezet en daarna weer terug in ibm3"
#       },
#       {
#         "description": "Generatoren van ibm3 en ibm4 omgedraaid"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #74
# {
#   "case_id": "IBM4_C25_15-Jun-15_08-Jul-15",
#   "result": {
#     "fault_location": {
#       "name": "Cryo",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "afkoelrate wat langzaam",
#       "klein bijgeluidje mogelijk door afzetting van vervuiling",
#       "temperatuur cryo gezakt naar 15,5\u00b0C (was ca.18,5 -19\u00b0C: 3\u00b0C gezakt)"
#     ],
#     "fault_reason": [
#       {
#         "name": "inlek in pomp zelf was goed"
#       },
#       {
#         "name": "mogelijk door afzetting van vervuiling"
#       },
#       {
#         "name": "vervuiling vrijgekomen van de koudste trap na de tweede keer regenereren"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)"
#       },
#       {
#         "description": "Compressor afgevuld op 265 psi"
#       },
#       {
# ...
# {
#   "case_id": "IBM4_C47_09-Dec-19_09-Dec-19",
#   "result": {
#     "fault_location": {
#       "name": "pompje",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Glycol lekkage"
#     ],
#     "fault_reason": [
#       {
#         "name": "slangtule bij pompje afgebroken"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "slangtule vervangen"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #83
# {
#   "case_id": "IBM4_C48_09-Apr-20_09-Apr-20",
#   "result": {
#     "fault_location": {
#       "name": "ventilator",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Piepgeluiden uit de bron"
#     ],
#     "fault_reason": [
#       {
#         "name": "lagertje van ventilator versleten"
#       }
#     ],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #84
# {
#   "case_id": "IBM4_C49_08-Jun-20_08-Jun-20",
#   "result": {
#     "fault_location": {
#       "name": "Neutralizer",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Sluiting in acc.grid"
#     ],
#     "fault_reason": [
#       {
#         "name": "ring verkeerd gemonteerd"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Anode gestraald, binnenkant machine blisters verwijdert"
#       },
#       {
#         "description": "Neutralizer op tafel schoongemaakt en in ibm gezet"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #85
# {
#   "case_id": "IBM4_C4_29-Oct-13_29-Oct-13",
#   "result": {
#     "fault_location": {
#       "name": "Persluchtklep van HV-klep",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "HV-klep (gate valve-1) niet meer te bedienen vanuit de manual mode"
#     ],
#     "fault_reason": [
#       {
#         "name": "Lucifer bestaat niet meer en is overgenomen door Parker en deze kende de klep niet"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Persluchtklep van HV-klep vervangen. (Magneetventiel)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #86
# {
#   "case_id": "IBM4_C52_03-Aug-20_04-Aug-20",
#   "result": {
#     "fault_location": {
#       "name": "Neutralizer",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "werkt moeizaam / niet",
#       "geen emissie",
#       "programma gaat niet verder"
#     ],
#     "fault_reason": [
#       {
#         "name": "Mogelijke oorzaak was: geleiding over keramische isolatoren bij aansluiting op bron"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Herhaaldelijk schoonmaken / ook nieuwe kath., nieuw Mo-diafragma, binnenkant gestraald"
#       },
#       {
#         "description": "Controlle aansluitingen: alle drie goed (0 ohm)"
#       },
#       {
#         "description": "schoonmaken"
#       },
#       {
#         "description": "schoonstralen van isolatoren"
#       },
#       {
#         "description": "schoonstralen van lange Al-oxide buis"
#       },
#       {
#         "description": "neutralizer gecontroleerd, zo goed als 'nieuw'"
#       },
#       {
#         "description": "1 nacht laten pompen"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #87
# {
#   "case_id": "IBM4_C53_26-Oct-20_26-Oct-20",
#   "result": {
#     "fault_location": {
#       "name": "Cryopomp",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "koelt maar tot 150K",
#       "zakt niet verder dan 150K",
#       "druk op meter varieert tussen: 5.25 - 6.0 bar",
#       "fluctiatie: 3/4 bar"
#     ],
#     "fault_reason": [
#       {
#         "name": "koelwater is onvoldoende om beide comperessoren te koelen"
#       }
#     ],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #88
# {
#   "case_id": "IBM4_C61_20-Dec-21_20-Dec-21",
#   "result": {
#     "fault_location": {
#       "name": "Neutralizer",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "werkt niet"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Neutralizer uit IBM 3 gehaald, deze werkt prima"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #89
# {
#   "case_id": "IBM4_C65_03-Aug-22_04-Aug-22",
#   "result": {
#     "fault_location": {
#       "name": "Vacuum",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "niet meer goed",
#       "Druk niet lager dan in 10-5 gebied"
#     ],
#     "fault_reason": [
#       {
#         "name": "HV klept lekt waarschijnlijk"
#       },
#       {
#         "name": "HV klep lekt blijkbaar"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Nieuwe O-ring voordeur gemonteerd"
#       },
#       {
#         "description": "controle op lekkage door isolatieklep voorpomp"
#       },
#       {
#         "description": "loshalen / nakijkenmoet nog gebeuren"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #90
# {
#   "case_id": "IBM4_C66_22-Aug-22_22-Aug-22",
#   "result": {
#     "fault_location": {
#       "name": "Cryo",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "druk in de kamer na 4 dagen: 16 mbar",
#       "100h / 150l / 16mbar: 5 * 10-3 mbar / 2 min"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "Cryo laten afkoelen met vacuum in de kamer (aparte pomp: 3 * 10-2 mbar)"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #91
# {
#   "case_id": "IBM4_C68_06-Sept-22_08-Sept-22",
#   "result": {
#     "fault_location": {
#       "name": "Tafellager",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "IBM4 kapot",
#       "Vacuum 9 * 10-5 mbar",
#       "inlek vanmorgen: 4.3 * 10-2 mbar / 1 min"
#     ],
#     "fault_reason": [
#       {
#         "name": "Tafellager is lek / onbruikbaar"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "nieuwe doorvoer / met partiele afzuiging: 0.4 mbar"
#       },
#       {
#         "description": "shutter doorvoer gelektest: helemaal goed / weer terug gemonteerd"
#       },
#       {
#         "description": "coax aansluiting afgedopt met swagelok"
#       },
#       {
#         "description": "Dop op tafel schoongemaakt / opnieuw gemonteerd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #92
# {
#   "case_id": "IBM4_C70_03-Oct-22_06-Oct-22",
#   "result": {
#     "fault_location": {
#       "name": "IBM4",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Synchronisatie tafelhoek werkt niet",
#       "arm niet in beweging",
#       "Home bleef staan",
#       "Doorlopend arcnet storingen",
#       "Muis was zeer traag (> 30sec)",
#       "PLC / computer(?) Op tilt: tegenstrijdige foutmeldingen",
#       "foutmelding: clamp in hoge positie (in werkelijkheid was deze laag)",
#       "shutter geblokkeerd en synchronisatie was niet mogelijk",
#       "trage muisreactie in servicemode (30sec)"
#     ],
#     "fault_reason": [
#       {
#         "name": "tegenstrijdige foutmeldingen"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Nieuwe fillamenten in iongauge / deze teruggeplaatst"
#       },
#       {
#         "description": "Schermplaat aan etskant gemonteerd"
#       },
#       {
#         "description": "Verstellen van de potmeter(achterkant iongauge-kast)"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #93
# {
#   "case_id": "IBM4_C71_10-Oct-22_10-Oct-22",
#   "result": {
#     "fault_location": {
#       "name": "Compressor",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "veel He weg",
#       "temp. 24K"
#     ],
#     "fault_reason": [
#       {
#         "name": "Waarschijnlijk koelwaterleiding doorgecorodeerd"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Comperssor van ibm3 op ibm4 gezet"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #94
# {
#   "case_id": "IBM4_C72_14-Oct-22_14-Oct-22",
#   "result": {
#     "fault_location": {
#       "name": "rotatie tafel",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "vacuumproblemen"
#     ],
#     "fault_reason": [
#       {
#         "name": "haarscheur in kap"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Kap hersteld door Wennekers in Mill, Nieuwe shielding gemaakt en geplaatst"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #95
# {
#   "case_id": "IBM4_C75_28-Feb-23_28-Feb-23",
#   "result": {
#     "fault_location": {
#       "name": "N-module (cryo onboard module)",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "voorpomp wordt niet gestart bij regeneratie"
#     ],
#     "fault_reason": [
#       {
#         "name": "N-module 2-de hands"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "voorpomp handmatig aanzetten"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #96
# {
#   "case_id": "IBM4_C76_13-Mar-23_13-Mar-23",
#   "result": {
#     "fault_location": {
#       "name": "compressor",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "leek He te verliezen"
#     ],
#     "fault_reason": [
#       {
#         "name": "meter bleek te blijven hangen"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Marc tikte op de meter"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #97
# {
#   "case_id": "IBM4_C78_08-May-23_08-May-23",
#   "result": {
#     "fault_location": {
#       "name": "Bron",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Uitval tijdens proces",
#       "communicatie fout"
#     ],
#     "fault_reason": [
#       {
#         "name": "mogelijk door communicatie fout"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Kwartier afgepompt, communicatie fout, was zelf hersteld"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #98
# {
#   "case_id": "IBM4_C80_15-Jun-23_15-Jun-23",
#   "result": {
#     "fault_location": {
#       "name": "Glycolpomp",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "werkt niet"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "ontluchten van het systeem"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #99
# {
#   "case_id": "IBM4_C81_08-Sept-23_08-Sept-23",
#   "result": {
#     "fault_location": {
#       "name": "Glycolpomp",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "lekkage",
#       "lucht terugkomen in het koelcircuit"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "kunststof aansluitdeel slang vervangen door een messing deel"
#       },
#       {
#         "description": "schroef van het waterfilter een beetje losdraaien zodat de lucht weg kan, daarna weer vastdraaien"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #100
# {
#   "case_id": "IBM4_C82_14-Nov-23_14-Nov-23",
#   "result": {
#     "fault_location": {
#       "name": "Machine",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Machine viel uit tijdens proces"
#     ],
#     "fault_reason": [
#       {
#         "name": "sluiting"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "grid van bron schoongemaakt"
#       },
#       {
#         "description": "rvs beschermplaat van arm compleet door geetst en heeft Walter met spoed 2 nieuwe gemaakt"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #101
# {
#   "case_id": "IBM4_C84_18-Apr-24_26-Apr-24",
#   "result": {
#     "fault_location": {
#       "name": "PLC",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "PLC schrijft programma weg in draft terwijl dit version 25 zou moeten zijn",
#       "CPU in storing",
#       "machine start niet goed op",
#       "veel onlogische problemen metname bij het synchroniseren van de motorcontrol en de aansturing MFC",
#       "motor stopt steeds na een klein stapje en vergeet de positie",
#       "machine steeds meer moeite heeft om de filamenten op te starten"
#     ],
#     "fault_reason": [
#       {
#         "name": "waarschijnlijk valt de CPU in storing"
#       },
#       {
#         "name": "mogelijk wordt de controller slechter"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Gebuikte ARC-NET kaart besteld (BRARCIF-0T) PO6404"
#       },
#       {
#         "description": "CPU (MCCP32-022) besteld op PO6427"
#       },
#       {
#         "description": "CPU en ARC-NET kaart gemonteerd, keuze schakelaars op de juiste positie gezet"
#       },
#       {
#         "description": "Div. Kaarten random gewisseld, keuzeschakelaars weer aangepast"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #102
# {
#   "case_id": "IBM4_C85_15-May-24_23-May-24",
#   "result": {
#     "fault_location": {
#       "name": "PLC/ARC-net card",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "wissel je van ARC-net kaart geeft dit problemen en vallen er outputs weg",
#       "soms valt de hele unit uit met een communicatie storing",
#       "rode tekst met version 300.184 not for release",
#       "shutter open terwijl deze dicht is",
#       "motor control vergeet de Arm position",
#       "Etch source van een gele driehoek naar een groen rondje gaat, proces kwam niet verder",
#       "arm position is niet te bedienen, blijft in storing vallen",
#       "platen shutter position blijft in storing vallen"
#     ],
#     "fault_reason": [
#       {
#         "name": "problemen van de motor control lijken van de PLC/instellingen ARC-net kaart te komen"
#       },
#       {
#         "name": "tekening komt niet overeen met de PLC"
#       },
#       {
#         "name": "hardware in orde, problemen in de PLC/Arc-net kaart"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "PLC compleet overgezet naar IBM 4"
#       },
#       {
#         "description": "home positie aangepast, sleuf in de steun uitgevijlt en daarna op -90 gr. = 0 graden afgesteld"
#       },
#       {
#         "description": "complete PLC 2 gewisseld afkomstig van IBM3"
#       },
#       {
#         "description": "div. PLC kaarten e.d. besteld om een voorraad aan te leggen"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #103
# {
#   "case_id": "IBM4_C86_17-Jun-24_17-Jun-24",
#   "result": {
#     "fault_location": {
#       "name": "filamenten",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "Machine geeft problemen met het opstarten"
#     ],
#     "fault_reason": [],
#     "fault_measures": [
#       {
#         "description": "controller gewisseld met Ebay aankoop"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #104
# {
#   "case_id": "IBM4_C87_27-Jun-24_27-Jun-24",
#   "result": {
#     "fault_location": {
#       "name": "Pc",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "vastgelopen",
#       "geeft blauw scherm"
#     ],
#     "fault_reason": [
#       {
#         "name": "windows fout mogelijk geheugen gerelateerd"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Martin heeft e.e.a. aan de pc gecontroleerd, voorlopig werkt deze weer"
#       }
#     ],
#     "resolution_status": "Resolved"
#   }
# }
# Missing 'fault_location' in entry #105
# {
#   "case_id": "IBM4_C88_03-Jul-24_03-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Pc",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [
#       "enorm traag",
#       "harde schijf blijft actief"
#     ],
#     "fault_reason": [],
#     "fault_measures": [],
#     "resolution_status": "Unknown"
#   }
# }
# Missing 'fault_location' in entry #106
# {
#   "case_id": "IBM4_C90_30-Jul-24_30-Jul-24",
#   "result": {
#     "fault_location": {
#       "name": "Pc",
#       "machine": "IBM4"
#     },
#     "fault_symptoms": [],
#     "fault_reason": [
#       {
#         "name": "data paden weg in Pcplus programma"
#       }
#     ],
#     "fault_measures": [
#       {
#         "description": "Martin heeft de software opnieuw geinstalleerd"
#       }
#     ],
#     "resolution_status": "Unknown"
#   }
# }

# %%
# IMPORT ENTITIES FROM ENGLISH MANUAL BOOK

# Load the manual_book_fault_reports.json
# -------------------------
file_manual_book = os.path.join(folder_path, "manual_book_fault_reports.json")

with open(file_manual_book, "r") as f:
    data_manual_book = json.load(f)

print(f"Loaded {len(data_manual_book)} cases from manual_book_fault_reports.json")

with driver.session() as session:
    for entry in data_manual_book:
        if "fault_location" in entry:  # because this file doesn't wrap each entry in {"result": ...}
            session.write_transaction(create_fault_graph, entry)
        else:
            print("⚠️ Skipped invalid entry:", entry)

print("✅ Manual book data imported into Neo4j successfully!")
# Out:
# Loaded 28 cases from manual_book_fault_reports.json
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_6254/3261343364.py:12: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_6254/3261343364.py:15: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(create_fault_graph, entry)
# ✅ Manual book data imported into Neo4j successfully!

# %% [markdown]
# CONNECTING TO LOCAL DB

# %%
from neo4j import GraphDatabase

# Local Neo4j settings
uri = "bolt://localhost:7687"
username = "neo4j"
password = "test12345"

# Connect to Neo4j
driver = GraphDatabase.driver(uri, auth=(username, password))

# Quick test: run a Cypher query
with driver.session() as session:
    result = session.run("RETURN 'Neo4j connection successful!' AS message")
    print(result.single()["message"])

driver.close()
# Out:
# Neo4j connection successful!

# %%
import os
from dotenv import load_dotenv
import json

def create_fault_graph(tx, data):
    loc_name = data["fault_location"]["name"]
    machine = data["fault_location"].get("machine", None)
    # Create or merge FaultLocation node
    if machine:
        tx.run(
            """
            MERGE (fl:FaultLocation {name: $loc_name})
            SET fl.machines = apoc.coll.toSet(coalesce(fl.machines, []) + [$machine])
            """,
            loc_name=loc_name,
            machine=machine
        )
    else:
        tx.run(
            """
            MERGE (fl:FaultLocation {name: $loc_name})
            """,
            loc_name=loc_name
        )

    # Fault Symptoms, Reasons, Measures
    for symptom in data.get("fault_symptoms", []):
        tx.run(
            """
            MERGE (fs:FaultSymptom {description: $symptom})
            WITH fs
            MATCH (fl:FaultLocation {name: $loc_name})
            MERGE (fl)-[:HAS_FAULT]->(fs)
            """,
            symptom=symptom,
            loc_name=loc_name
        )
        # Fault Reason
        for reason in data.get("fault_reason", []):
            tx.run(
                """
                MERGE (fr:FaultReason {name: $reason_name})
                WITH fr
                MATCH (fs:FaultSymptom {description: $symptom})
                MERGE (fs)-[:CAUSED_BY]->(fr)
                """,
                reason_name=reason["name"],
                symptom=symptom
            )
        # Fault Measure
        for measure in data.get("fault_measures", []):
            tx.run(
                """
                MERGE (fm:FaultMeasure {description: $measure_desc})
                WITH fm
                MATCH (fs:FaultSymptom {description: $symptom})
                MERGE (fs)-[r:MITIGATED_BY]->(fm)
                SET r.resolution_status = $status
                """,
                measure_desc=measure["description"],
                symptom=symptom,
                status=data.get("resolution_status", "Unknown")
            )

def load_json_file(filepath):
    with open(filepath, "r") as f:
        if filepath.endswith(".jsonl"):
            return [json.loads(line) for line in f]
        else:
            return json.load(f)

folder_path = "/Users/wbm/Documents/BIT/Thesis/graphRAG-industrial-fault-diagnosis/data/processed"
files = [
    "baml_extracted_20_cases.json",
    "baml_extracted_remaining_cases.json",
    "manual_book_fault_reports.json"
]
# Add more files as needed

all_cases = []

for file in files:
    path = os.path.join(folder_path, file)
    print(f"Loading {file} ...")
    data = load_json_file(path)
    all_cases.extend(data)

print(f"Loaded total cases: {len(all_cases)}")

with driver.session() as session:
    for i, entry in enumerate(all_cases):
        # Handle "result" or flat dict
        if "result" in entry:
            data = entry["result"]
        else:
            data = entry
        if "fault_location" in data:
            session.execute_write(create_fault_graph, data)
        else:
            print(f"Skipping case #{i}: missing fault_location")
print("All cases imported into local Neo4j!")
driver.close()
# Out:
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_39007/1758827117.py:90: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# [#E849]  _: <CONNECTION> error: Failed to read from defunct connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687))): OSError('No data')
# Transaction failed and will be retried in 1.0783075397400381s (Failed to read from defunct connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687))))
# Loading baml_extracted_20_cases.json ...
# Loading baml_extracted_remaining_cases.json ...
# Loading manual_book_fault_reports.json ...
# Loaded total cases: 135
# All cases imported into local Neo4j!

# %% [markdown]
# Pushing New Property "case_id" for each Nodes
#
# This is done for traceability

# %%
from neo4j import GraphDatabase
import json
import os

# Load the JSON file (20 cases)
folder_path = "/Users/wbm/Documents/BIT/Thesis/graphRAG-industrial-fault-diagnosis/data/processed"
file_20_cases = os.path.join(folder_path, "baml_extracted_20_cases.json")
file_remaining_cases = os.path.join(folder_path, "baml_extracted_remaining_cases.json")

with open(file_20_cases, "r") as f:
    data_20_cases = json.load(f)

with open(file_remaining_cases, "r") as f:
    data_remaining_cases = json.load(f)

# Setup Neo4j driver
from dotenv import load_dotenv
load_dotenv()
uri = os.getenv("NEO4J_URI")
username = os.getenv("NEO4J_USER")
password = os.getenv("NEO4J_PASS")
driver = GraphDatabase.driver(uri, auth=(username, password))

def update_case_ids(tx, case_id, data):
    # FaultLocation
    tx.run(
        """
        MATCH (n:FaultLocation {name: $loc_name})
        SET n.case_ids = coalesce(n.case_ids, []) + CASE WHEN $case_id IN coalesce(n.case_ids, []) THEN [] ELSE [$case_id] END
        """,
        loc_name=data["fault_location"]["name"],
        case_id=case_id
    )

    # FaultSymptoms
    for symptom in data["fault_symptoms"]:
        tx.run(
            """
            MATCH (n:FaultSymptom {description: $symptom})
            SET n.case_ids = coalesce(n.case_ids, []) + CASE WHEN $case_id IN coalesce(n.case_ids, []) THEN [] ELSE [$case_id] END
            """,
            symptom=symptom,
            case_id=case_id
        )

    # FaultReasons
    for reason in data["fault_reason"]:
        tx.run(
            """
            MATCH (n:FaultReason {name: $reason_name})
            SET n.case_ids = coalesce(n.case_ids, []) + CASE WHEN $case_id IN coalesce(n.case_ids, []) THEN [] ELSE [$case_id] END
            """,
            reason_name=reason["name"],
            case_id=case_id
        )

    # FaultMeasures
    for measure in data["fault_measures"]:
        tx.run(
            """
            MATCH (n:FaultMeasure {description: $measure_desc})
            SET n.case_ids = coalesce(n.case_ids, []) + CASE WHEN $case_id IN coalesce(n.case_ids, []) THEN [] ELSE [$case_id] END
            """,
            measure_desc=measure["description"],
            case_id=case_id
        )

# Now update the graph nodes for all 20 cases
with driver.session() as session:
    for entry in data_20_cases + data_remaining_cases:
        case_id = entry.get("case_id")
        data = entry["result"]
        session.write_transaction(update_case_ids, case_id, data)

driver.close()
print("Case IDs successfully added to all entities (20 cases + remaining cases)!")
# Out:
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_39007/2817769021.py:73: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(update_case_ids, case_id, data)
# Case IDs successfully added to all entities (20 cases + remaining cases)!

# %% [markdown]
# Push new property "source_image" to all related nodes

# %%
import os
import json
from neo4j import GraphDatabase
from dotenv import load_dotenv

# Load data
folder_path = "/Users/wbm/Documents/BIT/Thesis/graphRAG-industrial-fault-diagnosis/data/processed"
file_manual_book = os.path.join(folder_path, "manual_book_fault_reports.json")
with open(file_manual_book, "r") as f:
    data_manual_book = json.load(f)

# Neo4j setup
load_dotenv()
uri = os.getenv("NEO4J_URI")
username = os.getenv("NEO4J_USER")
password = os.getenv("NEO4J_PASS")
driver = GraphDatabase.driver(uri, auth=(username, password))

def update_source_image(tx, source_image, data):
    # FaultLocation
    tx.run("""
        MATCH (n:FaultLocation {name: $loc_name})
        SET n.source_image = $source_image
        """,
        loc_name=data["fault_location"]["name"],
        source_image=source_image
    )
    # FaultSymptoms
    for symptom in data["fault_symptoms"]:
        tx.run("""
            MATCH (n:FaultSymptom {description: $symptom})
            SET n.source_image = $source_image
            """,
            symptom=symptom,
            source_image=source_image
        )
    # FaultReasons
    for reason in data["fault_reason"]:
        tx.run("""
            MATCH (n:FaultReason {name: $reason_name})
            SET n.source_image = $source_image
            """,
            reason_name=reason["name"],
            source_image=source_image
        )
    # FaultMeasures
    for measure in data["fault_measures"]:
        tx.run("""
            MATCH (n:FaultMeasure {description: $measure_desc})
            SET n.source_image = $source_image
            """,
            measure_desc=measure["description"],
            source_image=source_image
        )

with driver.session() as session:
    for entry in data_manual_book:
        source_image = entry.get("source_image")
        if source_image:
            session.write_transaction(update_source_image, source_image, entry)
        else:
            print("Skipped entry with no source_image:", entry)

driver.close()
print("source_image property successfully added to all entities from manual_book_fault_reports.json!")
# Out:
# /var/folders/15/_nms3dx938z02zxw1j0ns_4h4n_pl4/T/ipykernel_39007/2577595690.py:60: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(update_source_image, source_image, entry)
# source_image property successfully added to all entities from manual_book_fault_reports.json!
