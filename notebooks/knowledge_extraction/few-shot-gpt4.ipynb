# %%
# Load OpenAI API-Key
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
from baml_client.sync_client import b
from baml_client.types import FaultReport

# %%
# few-shot 20 cases for evaluation

import json
from pathlib import Path

# Path to the few-shot cases JSONL file
input_path = Path("/Users/wbm/Documents/BIT/Research Topics/Potential Datasets/20_cases_for_baml_fewshot.jsonl")

# Load 20 log_text strings
log_entries = []
with open(input_path, "r", encoding="utf-8") as f:
    for line in f:
        log_entries.append(json.loads(line))  # Each line is a raw log string

# Collect the results
extracted_results = []

for i, log_text in enumerate(log_entries):
    print(f"🛠️ Processing case {i+1}/{len(log_entries)}")
    try:
        result: FaultReport = b.ExtractFaultInfo(log_text=log_text)
        extracted_results.append({
            "case_id": log_text.split("\n")[0].replace("Case-ID:", "").strip(),
            "result": result.model_dump()
        })
    except Exception as e:
        print(f" Failed to process case {i+1}: {e}")
        extracted_results.append({
            "case_id": log_text.split("\n")[0].replace("Case-ID:", "").strip(),
            "error": str(e)
        })

# Save the results to file
output_path = Path("baml_extracted_20_cases.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(extracted_results, f, indent=2, ensure_ascii=False)

print(f" Extraction completed! Saved to: {output_path}")
# Out:
# 🛠️ Processing case 1/20
# 2025-04-23T17:45:49.314 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 2884ms. StopReason: stop. Tokens(in/out): 2028/87
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamcu🛠️ Processing case 2/20
# rrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C15_23-Feb-15_23-Feb-15
#     Sources: storing
#     Issues:
#     - He-verlies/tekort in cryocompressor |  | Uit: 10,5bar  /  aan: 3,0 - 3,4bar  (40-50 psi) | Displacer maakt een wat hoog piepend/schrapend geluid | Temp. Is 11K |  | (Absorber vervangen: 6-10-'06) | CTI-Cryogenics | Helix technology Corp | 9600 compressor | P/N = 8135901G001 | SN = 94L0013912
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "cryocompressor",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "He-verlies/tekort",
#         "Displacer maakt een wat hoog piepend/schrapend geluid"
#       ],
#       "fault_reason": [],
#       "fault_measures": [],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "cryocompressor",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "He-verlies/tekort",
#         "Displacer maakt een wat hoog piepend/schrapend geluid"
#       ],
#       "fault_reason": [],
#       "fault_measures": [],
#       "resolution_status": "Unknown"
#     }
# 🛠️ Processing case 3/202025-04-23T17:45:52.795 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 3476ms. StopReason: stop. Tokens(in/out): 2028/134
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C26_21-Sep-16_22-Sep-16
#     Sources: reparatie, storing
#     Issues:
#     - Armkanteling werkt niet (voeding wel aan)   (let op: als shutterpos. In tussen positie is, werkt armkanteling niet) | Shutterpositie indicatie: tussenpositie  (Vlgs. Schema: PCB3 / jp6 / pen 2 en 3 verbinden voor dicht) (geel & rood op de stekker)
#     - JP6 los en pen 2 en 3 aan elkaar gesoldeerd.  (Shutter wordt niet gebruikt / eindschakelaar(s) zijn met jumper overbrugd)
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "Armkanteling",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Armkanteling werkt niet",
#         "Shutterpositie indicatie: tussenpositie"
#       ],
#       "fault_reason": [
#         {
#           "name": "Shutterpos. In tussen positie is, werkt armkanteling niet"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "JP6 los en pen 2 en 3 aan elkaar gesoldeerd"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "Armkanteling",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Armkanteling werkt niet",
#         "Shutterpositie indicatie: tussenpositie"
#       ],
#       "fault_reason": [
#         {
#           "name": "Shutterpos. In tussen positie is, werkt armkanteling niet"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "JP6 los en pen 2 en 3 aan elkaar gesoldeerd"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
# 2025-04-23T17:45:55.252 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 2453ms. StopReason: stop. Tokens(in/out): 2007/126
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc🛠️ Processing case 4/20
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C29_05-Jul-17_12-Jul-17
#     Sources: reparatie, Inspectie
#     Issues:
#     - IBM3 getest | Bron lijkt te werken | - controleren of de generator max. Vermogen haalt  (500W) | - probleem met tafel.  Draait wel, (ook onder vacuum), maar geen positie / rpm (?) detectie | Gevolg, proces start niet.
#     - Lichtsluisje van schijf van / onder tafel deed het niet. Schoongemaakt. Blauwe draad aangesoldeerd | Getest, lijkt de oorzaak.
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "tafel",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "geen positie / rpm detectie",
#         "proces start niet"
#       ],
#       "fault_reason": [
#         {
#           "name": "Lichtsluisje van schijf van / onder tafel deed het niet"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Schoongemaakt. Blauwe draad aangesoldeerd"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "tafel",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "geen positie / rpm detectie",
#         "proces start niet"
#       ],
#       "fault_reason": [
#         {
#           "name": "Lichtsluisje van schijf van / onder tafel deed het niet"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Schoongemaakt. Blauwe draad aangesoldeerd"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
# 🛠️ Processing case 5/202025-04-23T17:45:57.401 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 2146ms. StopReason: stop. Tokens(in/out): 1979/119
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C38_18-Nov-19_18-Nov-19
#     Sources: storing
#     Issues:
#     - Instellen snelheid rotatietafel ging goed.  Nulpositie vinden lukte niet.  Voeding ibm uit, weer aan | Positie kon toen wel gevonden worden | Conclusie: lichtsluisje werkt | Armpositie:  Homing lukt niet | reden:  voeding PM150 was uitgezet | Resolution Status: Resolved
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "rotatietafel",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Nulpositie vinden lukte niet",
#         "Homing lukt niet"
#       ],
#       "fault_reason": [
#         {
#           "name": "voeding PM150 was uitgezet"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Voeding ibm uit, weer aan"
#         }
#       ],
#       "resolution_status": "Resolved"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "rotatietafel",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Nulpositie vinden lukte niet",
#         "Homing lukt niet"
#       ],
#       "fault_reason": [
#         {
#           "name": "voeding PM150 was uitgezet"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Voeding ibm uit, weer aan"
#         }
#       ],
#       "resolution_status": "Resolved"
#     }
# 2025-04-23T17:46:00.064 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 2660ms. StopReason: stop. Tokens(in/out): 1976/113
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc🛠️ Processing case 6/20
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C45_26-Oct-20_26-Oct-20
#     Sources: reparatie
#     Issues:
#     - Acc.grid: sluiting tegen massa | Montage was goed, alles was schoon | oorzaak: keramiek van schoefjes die grid-set bij elkaar houden | Doorslag naar de ""deksel"" |  | actie: schoefjes vervangen door nieuwe met schone keramiek | resultaat:bron werkte goed
#     Resolution Status: N/A
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "Acc.grid",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": ["sluiting tegen massa"],
#       "fault_reason": [
#         {
#           "name": "keramiek van schoefjes die grid-set bij elkaar houden"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "schoefjes vervangen door nieuwe met schone keramiek"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "Acc.grid",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "sluiting tegen massa"
#       ],
#       "fault_reason": [
#         {
#           "name": "keramiek van schoefjes die grid-set bij elkaar houden"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "schoefjes vervangen door nieuwe met schone keramiek"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
# 🛠️ Processing case 7/202025-04-23T17:46:03.238 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 3170ms. StopReason: stop. Tokens(in/out): 1981/124
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamcurrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
# ...
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM4_C79_13-Jun-23_13-Jun-23
#     Sources: Storing
#     Issues:
#     - Opstartproblemen, HV-klep aan/uit/aan . Voorpomp  "stuiterde" | IBM4 1 nacht uit.  Werkte weer.
#     Resolution Status: Resolved
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "HV-klep",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [
#         "Opstartproblemen",
#         "Voorpomp stuiterde"
#       ],
#       "fault_reason": [],
#       "fault_measures": [],
#       "resolution_status": "Resolved"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "HV-klep",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [
#         "Opstartproblemen",
#         "Voorpomp stuiterde"
#       ],
#       "fault_reason": [],
#       "fault_measures": [],
#       "resolution_status": "Resolved"
#     }
#
# 2025-04-23T17:46:44.117 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 4618ms. StopReason: stop. Tokens(in/out): 1998/173
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamcurrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM4_C91_23-Sept-24_01-Oct-24
#     Sources: Storing, Reparatie
#     Issues:
#     - Stekker glycolpomp (380 volt) maakt sluiting, bijna doorgebrand.....    Op dit moment niet meer gebruiken | Spanning van machine gehaald, bij Reichelt nieuwe Hirschmann stak 3 en stasei 3 connectoren besteld.
#     - Nieuwe connectoren geplaast, kabel ingekort was doorgebrand, alles vernieuwd incl. adereind hulzen.
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "glycolpomp",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [
#         "Stekker maakt sluiting",
#         "bijna doorgebrand"
#       ],
#       "fault_reason": [
#         {
#           "name": "Stekker glycolpomp maakt sluiting"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Spanning van machine gehaald, bij Reichelt nieuwe Hirschmann stak 3 en stasei 3 connectoren besteld"
#         },
#         {
#           "description": "Nieuwe connectoren geplaast, kabel ingekort was doorgebrand, alles vernieuwd incl. adereind hulzen"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "glycolpomp",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [
#         "Stekker maakt sluiting",
#         "bijna doorgebrand"
#       ],
#       "fault_reason": [
#         {
#           "name": "Stekker glycolpomp maakt sluiting"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Spanning van machine gehaald, bij Reichelt nieuwe Hirschmann stak 3 en stasei 3 connectoren besteld"
#         },
#         {
#           "description": "Nieuwe connectoren geplaast, kabel ingekort was doorgebrand, alles vernieuwd incl. adereind hulzen"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
# ✅ Extraction completed! Saved to: baml_extracted_20_cases.json

# %%
import json
import time
from pathlib import Path

# Define file paths
input_path = Path("/Users/wbm/Documents/BIT/Research Topics/Potential Datasets/remaining_cases_for_baml_fewshot.jsonl")
output_path = Path("baml_extracted_remaining_cases.json")

# Load log entries
with open(input_path, "r", encoding="utf-8") as f:
    log_entries = [json.loads(line) for line in f]

# Retry logic
def extract_with_retry(log_text, retries=3, delay=30):
    for attempt in range(retries):
        try:
            result: FaultReport = b.ExtractFaultInfo(log_text=log_text)
            return result.model_dump()
        except Exception as e:
            if "rate limit" in str(e).lower() and attempt < retries - 1:
                print(f"⚠️ Rate limited. Waiting {delay}s before retrying (attempt {attempt+1}/{retries})...")
                time.sleep(delay)
            else:
                raise e

# Process each log entry
extracted_results = []
for i, log_text in enumerate(log_entries):
    case_id = log_text.split("\n")[0].replace("Case-ID:", "").strip()
    print(f" Processing case {i+1}/{len(log_entries)}: {case_id}")

    try:
        result = extract_with_retry(log_text)
        extracted_results.append({
            "case_id": case_id,
            "result": result
        })
    except Exception as e:
        print(f" Failed to process case {case_id}: {e}")
        extracted_results.append({
            "case_id": case_id,
            "error": str(e)
        })

# Save results
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(extracted_results, f, indent=2, ensure_ascii=False)

print(f"\n Extraction completed! Saved to: {output_path}")
# Out:
# 🛠️ Processing case 1/87: IBM3_C14_15-Jan-15_15-Jan-15
# 🛠️ Processing case 2/87: IBM3_C15_25-Mar-15_25-Mar-152025-04-23T17:54:33.832 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 8966ms. StopReason: stop. Tokens(in/out): 2243/209
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C14_15-Jan-15_15-Jan-15
#     Sources: storing
#     Issues:
#     - Bron startte niet door | (Massaflowmeter is niet helemaal goed /flow soms te hoog, maar dat staat los van dit probleem) | Neutralizer startte prima, emissie blijft vaak beperkt tot 24mA maar vrijsnel nadat het plasma in de bron gestart is de emissie gelijk aan de ontlading in de neutralizer | Het probleem is dat dan de bron een bundel moet geven en dit niet doet | Controle:Contact met excelerator-grid is goed  (<10 ohm.) | Anode bleek een dikke harde isolerende laag te hebben. Deze schoongeschuurd | Bron werkte gelijk maar ik was vergeten de afscherming in de kwartscilinder in de bron te schuiven | Dit gedaan, resultaat, oude probleem, geen bundel uit de bron |  | Kwartscilinder was niet vervangen en had bij anode veel coating | Er is een kans, dat daardoor via de afscherming de anode verbonden wordt met het binnenste grid | Schone kwartscilinder er in | Gelijk gestart bij 8*10-6 mbar base pressure => oude probleem geen bundel | 1 uur laten pompen tot 1,8*10-6  =>  startte gelijk, al volle emissie uit de neutralizer voordat het plasma in de bron ontstoken was | Laten doorlopen, probleemloos ook de processtappen met lagere bundelstroom  (Infinera's) |  | Conclusie: bron moet goed schoon zijn, goed contact met voorste grid, geen isolerende oxide(?)-lagen op anode.
#     Resolution Status: Resolved
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "Bron",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Bron startte niet door",
#         "emissie blijft vaak beperkt tot 24mA",
#         "oude probleem, geen bundel uit de bron"
#       ],
#       "fault_reason": [
#         {
#           "name": "Anode bleek een dikke harde isolerende laag te hebben"
#         },
#         {
#           "name": "Kwartscilinder was niet vervangen en had bij anode veel coating"
#         },
#         {
#           "name": "Er is een kans, dat daardoor via de afscherming de anode verbonden wordt met het binnenste grid"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Anode schoongeschuurd"
#         },
#         {
#           "description": "Schone kwartscilinder er in"
#         }
#       ],
#       "resolution_status": "Resolved"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "Bron",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Bron startte niet door",
#         "emissie blijft vaak beperkt tot 24mA",
#         "oude probleem, geen bundel uit de bron"
#       ],
#       "fault_reason": [
#         {
#           "name": "Anode bleek een dikke harde isolerende laag te hebben"
#         },
#         {
#           "name": "Kwartscilinder was niet vervangen en had bij anode veel coating"
#         },
#         {
#           "name": "Er is een kans, dat daardoor via de afscherming de anode verbonden wordt met het binnenste grid"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Anode schoongeschuurd"
#         },
#         {
#           "description": "Schone kwartscilinder er in"
#         }
#       ],
#       "resolution_status": "Resolved"
#     }
# 🛠️ Processing case 3/87: IBM3_C19_02-Jul-15_05-Nov-152025-04-23T17:54:35.982 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 2147ms. StopReason: stop. Tokens(in/out): 1947/92
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamcu
# rrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C15_25-Mar-15_25-Mar-15
#     Sources: reparatie
#     Issues:
#     - He bijgevuld van cryocompressor (Was 4 bar, nu 15,5bar) | door Martien van Hout D&M vacum systemen
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "cryocompressor",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [],
#       "fault_reason": [],
#       "fault_measures": [
#         {
#           "description": "He bijgevuld van cryocompressor (Was 4 bar, nu 15,5bar)"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "cryocompressor",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [],
#       "fault_reason": [],
#       "fault_measures": [
#         {
#           "description": "He bijgevuld van cryocompressor (Was 4 bar, nu 15,5bar)"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
# 🛠️ Processing case 4/87: IBM3_C20_18-Jan-16_18-Jan-162025-04-23T17:54:40.084 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 4098ms. StopReason: stop. Tokens(in/out): 2330/287
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C19_02-Jul-15_05-Nov-15
#     Sources: Onderhoud, Inspectie, reparatie
#     Issues:
#     - Onderhoud en lekzoeken aan compressor | Door William Claassen | - Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling) | - Lekzoeken na op druk te zijn gebracht. Lekkage gevonden bij adsorber aansluiting. Na vervanging was deze weg | Compressor afgevuld op 265 psi. Slangen zijn afgekopeld. Doel is om nu te zien of druk behouden blijft | Na 1 week kijken en laten weten aan William. Dan kunnen de slangen er op. Lage druk kant eerst | Als er dan pas He verlies op treedt licht het aan de pomp of de slangen.
#     - compressor naar VS:   warmte wisselaar vervangen
#     - De door Hi-VAC Uptime BV meegenomen compressor was getest. He-lekkage aan de heatexchanger. (Komt niet vaak voor) | Beste aanbod wat Humphey kon doen was € 6250 excl.btw voor revisie (€6950- adsober die teruggenomen wordt) | Compressor wordt opgestuurd naar VS | Alle kleppen, heatexchanger, condensator wordt vervangen. Compressor moet 7 jaar meekunnen. Zit 12 mnd gerantie op | Nieuw €11,000 (OEM)
#     - Compressor volledig gereviseerd | Adsorbervervangen, He bijgevuld.
#     - He-compressor aangesloten | Druk zoals afgeleverd:  16.9 bar    Na aansluiten, (eerst lage drukkant dan hoge druk kant), van slangen zelfde druk | Druk direct na aanzetten:  5,4 bar | Info van William:  Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo. (Afdichtingen lekken) | Als cryo afgekoeld is:80 psi is goed  /  120 - 140 psi  begint slecht te worden | De eindtemp. is maatgevend. Was 14K
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "Compressor",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Lekkage gevonden bij adsorber aansluiting",
#         "He-lekkage aan de heatexchanger",
#         "Druk direct na aanzetten: 5,4 bar",
#         "Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo"
#       ],
#       "fault_reason": [
#         {
#           "name": "Lekkage bij adsorber aansluiting"
#         },
#         {
#           "name": "He-lekkage aan de heatexchanger"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)"
#         },
#         {
#           "description": "Compressor afgevuld op 265 psi"
#         },
#         {
#           "description": "Compressor naar VS: warmte wisselaar vervangen"
#         },
#         {
#           "description": "Alle kleppen, heatexchanger, condensator wordt vervangen"
#         },
#         {
#           "description": "Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "Compressor",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Lekkage gevonden bij adsorber aansluiting",
#         "He-lekkage aan de heatexchanger",
#         "Druk direct na aanzetten: 5,4 bar",
#         "Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo"
#       ],
#       "fault_reason": [
#         {
#           "name": "Lekkage bij adsorber aansluiting"
#         },
#         {
#           "name": "He-lekkage aan de heatexchanger"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)"
#         },
#         {
#           "description": "Compressor afgevuld op 265 psi"
#         },
#         {
#           "description": "Compressor naar VS: warmte wisselaar vervangen"
#         },
#         {
#           "description": "Alle kleppen, heatexchanger, condensator wordt vervangen"
#         },
#         {
#           "description": "Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
# 🛠️ Processing case 5/87: IBM3_C25_20-Sep-16_20-Sep-162025-04-23T17:54:43.265 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 3177ms. StopReason: stop. Tokens(in/out): 2035/218
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C20_18-Jan-16_18-Jan-16
#     Sources: storing
#     Issues:
#     - Ionbeam-controller | Neutralizer wilde niet starten. Te weinig spanning op het scherm (37V) | Kabel naar print getest. Ok | Glasmann voedingen getest;  nieuw = 1001V /  oud = 996V | opm.Relais van print kan ratelen als Glasmann voeding geen 220V heeft. (Staat geen spanning op ingangen naar print) | Er komt pas spanning van Glasmann voeding, als deze vrijgegeven wordt door de ibm controller | Dit gebeurt pas, als de neutralizer wordt gestart nadat het Ar in de neutralizer stroomt.
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "Ionbeam-controller",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Neutralizer wilde niet starten",
#         "Te weinig spanning op het scherm (37V)"
#       ],
#       "fault_reason": [
#         {
#           "name": "Relais van print kan ratelen als Glasmann voeding geen 220V heeft"
#         },
#         {
#           "name": "Er komt pas spanning van Glasmann voeding, als deze vrijgegeven wordt door de ibm controller"
#         },
#         {
#           "name": "Dit gebeurt pas, als de neutralizer wordt gestart nadat het Ar in de neutralizer stroomt"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Kabel naar print getest. Ok"
#         },
#         {
#           "description": "Glasmann voedingen getest; nieuw = 1001V / oud = 996V"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "Ionbeam-controller",
#         "machine": "IBM3"
#       },
#       "fault_symptoms": [
#         "Neutralizer wilde niet starten",
#         "Te weinig spanning op het scherm (37V)"
#       ],
#       "fault_reason": [
#         {
#           "name": "Relais van print kan ratelen als Glasmann voeding geen 220V heeft"
#         },
#         {
#           "name": "Er komt pas spanning van Glasmann voeding, als deze vrijgegeven wordt door de ibm controller"
#         },
#         {
#           "name": "Dit gebeurt pas, als de neutralizer wordt gestart nadat het Ar in de neutralizer stroomt"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Kabel naar print getest. Ok"
#         },
#         {
#           "description": "Glasmann voedingen getest; nieuw = 1001V / oud = 996V"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
# 2025-04-23T17:54:45.723 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 2454ms. StopReason: stop. Tokens(in/out): 2048/144
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamc🛠️ Processing case 6/87: IBM3_C27_27-Sep-16_24-Nov-16
# urrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM3_C25_20-Sep-16_20-Sep-16
#     Sources: reparatie
#     Issues:
# ...
# rrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM4_C88_03-Jul-24_03-Jul-24
#     Sources: Storing
#     Issues:
#     - Pc enorm traag, harde schijf blijft actief.
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "Pc",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [
#         "enorm traag",
#         "harde schijf blijft actief"
#       ],
#       "fault_reason": [],
#       "fault_measures": [],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "Pc",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [
#         "enorm traag",
#         "harde schijf blijft actief"
#       ],
#       "fault_reason": [],
#       "fault_measures": [],
#       "resolution_status": "Unknown"
#     }
# 2025-04-23T18:00:16.868 [BAML INFO] Function ExtractFaultInfo:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 2730ms. StopReason: stop. Tokens(in/out): 1937/99
#     ---PROMPT---
#     system: You are an expert in analyzing technical maintenance logs.
#
#         Extract the following entities:
#         - fault_location: the component with issue (add machine: IBM3/IBM4 if mentioned)
#         - fault_symptoms: all observable problems or symptoms.
#         - fault_reason: the stated causes of the issue (if any) + certainty
#         - fault_measures: steps taken to resolve the issue + resolution_status
#
#         Here are examples of extracting structured data:
#
#         Examples 1:
#             log_text: "Case-ID: IBM3_C22_03-Aug-16_04-Aug-16\nSources: storing, Storing, reparatie\nIssues:\n- Probleem: Beamcurrent tussen 300 - 200mA  (als je langzaam met de hand zakt tot 150mA)  Niet lager.        | Beamboard getest. Lijkt te werken. Beamcurrent start op een hoge waarde (ca. 300mA) en zakt langzaam.          | Besturing gaat door bij 200mA (Phaco) maar niet bij 100 mA Infinera). Schakelt af op \"\"out of tollerance\"\".         | Oorzaak: Comdel CX-600S generator  (SN 31141315)   (11-6-2000)        \n- Niet goed Generator Comdel CX-600S  SN 31141315    part: FP3114RB         | Werkt gedeeltelijk  (150mA - 300mA beamcurrent)   (wel voldoende vermogen: 500W, manual goed instelbaar))         |  - Je ruikt pertinax, mogelijk condensator bijna defect.         |  - Beamcurrent slechts instelbaar tussen 300mA - 200mA  (150mA net)        \n- Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator). (6-9-1999). CX-600W. SN: 468  part: FP3114R1. I-beam:   80 - 300mA   100mA: 205W |    200mA 311W |    300mA: 437W\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Generator", machine: "IBM3"},
#                 fault_symptoms: ["Beamcurrent tussen 300 - 200mA", "Schakelt af op out of tollerance", "ruikt pertinax"],
#                 fault_reason: [{name: "Niet goed Generator Comdel CX-600S"}, {name: "mogelijk condensator bijna defect"}],
#                 fault_measures: [{description: "Vervangen door zelf gerepareerde generator (nieuwe voedingscondensator)"}],
#                 resolution_status: "Resolved"
#             }
#
#         Examples 2:
#         log_text: "Case-ID: IBM3_C21_19-Jul-16_01-Aug-16\nSources: storing, reparatie\nIssues:\n- Werkte niet, interface kaart gewisseld. | Heeft 1x gewerkt, na 5 sec 200mA beam viel alles uit. | Interface kaart goed.    Storing: B fail. |   Oorzaak:   waarschijnlijk sluiting bij een van de powertransistors.  | \n- Van het beamboard de powertransistors losgehaald. Bij een transistor, was een zwart vlekje in de siliconen isolatie padje te zien (onder transistor).            | Lijkt grafitisatie van de siliconen. Deze vervangen door keramische isolatieplaatjes (beide transistors).            | 7815 voor de zekerheid ook vervangen.  Beamboard AE 02535E4499   powertransistor-unit 67539  99           \nResolution Status: Unknown"
#             output: {
#                 fault_location: {name: "beamboard", machine: "IBM3"},
#                 fault_symptoms: ["Werkte niet"],
#                 fault_reason: [{name: "waarschijnlijk sluiting bij een van de powertransistors"},
#                   {name: "een zwart vlekje in de siliconen isolatie padje"},
#                   {name: "Lijkt grafitisatie van de siliconen"},
#                   {name: "Deze vervangen door keramische isolatieplaatjes (beide transistors)"}
#                   ],
#                 fault_measures: [{description: "vervangen door keramische isolatieplaatjes (beide transistors)"}],
#                 resolution_status: "Unknown"
#             }
#
#         Example 3:
#         log_text: "Case-ID: IBM4_C29_06-Dec-16_06-Dec-16\nSources: Reparatie\nIssues:\n- Cryopomp is gereviseerd door High Vac. Uptime. CTI OB250F cryopomp, SN J06537588 | Na montage bleek dat de voorpomp niet automatisch start met regenereren. PO. 2307 | Deze in servicemode aangezet. Na paar uur was temp 11 K | Echter nieuwe controller communiceert niet met machine   SN: 87F950627 | Oorzaak: Relais--instellingen  (zie hiernaast)       | Aangepast, werkt nu. | PN: 8113036G001. |  | Hallo Paul,09-Dec-16 | Dit heeft te maken met de relais settings. | In de bijlage een overview alsmede de wijze waarop deze aan te passen zijn. We kunnen dit ook samen per telefoon doen indien gewenst. | Settings voor de IBM machine moeten zijn: | Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track | Deze beide signalen gaan naar de IBM controller als input. | Graag de juiste module weer bij de juiste pomp steken in verband met de diode calibratie gegevens van de temperatuur uitlezing. | Met vriendelijke groet \/  Best regards, | William Claassen |  | \nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Cryopomp", machine: "IBM4"},
#                 fault_symptoms: ["voorpomp niet automatisch start met regenereren"],
#                 fault_reason: [{name: "Relais--instellingen"}],
#                 fault_measures: [{description: "Relais 1 = 2nd stage temp 20-22K. | Relais 2 = Regen track"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 4:
#         log_text: "Case-ID: IBM4_C41_04-Jul-18_04-Jul-18\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: | IBM proces starte niet. | Reden: Kwam niet door de opstart-procedure heen. (haalde 300 mA niet). | Aanpassing:Waarde verandert in de setup: van 300 naar 200 mA. | Probleem opgelost.\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["proces starte niet"],
#                 fault_reason: [{name: "Kwam niet door de opstart-procedure heen. (haalde 300 mA niet)"}],
#                 fault_measures: [{description: "Waarde verandert in de setup: van 300 naar 200 mA"}],
#                 resolution_status: "Resolved"
#             }
#
#         Example 5:
#         log_text: "Case-ID: IBM4_C51_03-Jul-20_03-Jul-20\nSources: Storing & Reparatie\nIssues:\n- Neutralizer: Blijft problemen geven. meerdere keren schoongemaakt, ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V. | Probleem:  geen emissie, daarom start ibm-opstart programma niet door | actie:Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin. | resultaat: Start goed op, 20 min laten draaien\nResolution Status: Resolved"
#             output: {
#                 fault_location: {name: "Neutralizer", machine: "IBM4"},
#                 fault_symptoms: ["ontlading start gelijk op 300mA \/ spanning is zeer laag: 254V", "geen emissie", "opstart programma niet door"],
#                 fault_reason: [],
#                 fault_measures: [{description: "Nieuwe Ta-cathode, nieuwe boutjes, nieuw diafragma erin"}],
#                 resolution_status: "Resolved"
#             }
#
#     Now extract entities from the following log:
#     Maintenance Log:
#         ---
#         Case-ID: IBM4_C90_30-Jul-24_30-Jul-24
#     Sources: Reparatie
#     Issues:
#     - Pc opgeschoond, data paden weg in Pcplus programma, Martin heeft de software opnieuw geinstalleerd.
#     Resolution Status: Unknown
#         ---
#
#         Answer in JSON using this schema:
#     {
#       fault_location: {
#         name: string,
#         machine: 'IBM3' or 'IBM4',
#       },
#       fault_symptoms: string[],
#       fault_reason: [
#         {
#           name: string,
#         }
#       ],
#       fault_measures: [
#         {
#           description: string,
#         }
#       ],
#       resolution_status: 'Resolved' or 'Unknown',
#     }
#
#     ---LLM REPLY---
#     ```json
#     {
#       "fault_location": {
#         "name": "Pc",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [],
#       "fault_reason": [
#         {
#           "name": "data paden weg in Pcplus programma"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Martin heeft de software opnieuw geinstalleerd"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#     ```
#     ---Parsed Response (class FaultReport)---
#     {
#       "fault_location": {
#         "name": "Pc",
#         "machine": "IBM4"
#       },
#       "fault_symptoms": [],
#       "fault_reason": [
#         {
#           "name": "data paden weg in Pcplus programma"
#         }
#       ],
#       "fault_measures": [
#         {
#           "description": "Martin heeft de software opnieuw geinstalleerd"
#         }
#       ],
#       "resolution_status": "Unknown"
#     }
#
# ✅ Extraction completed! Saved to: baml_extracted_remaining_cases.json

# %%
with open("baml_extracted_remaining_cases.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Count only entries that have a 'result' key (not 'error')
successful = [entry for entry in data if "result" in entry]
failed = [entry for entry in data if "error" in entry]

print(f"Successfully extracted: {len(successful)}")
print(f"Failed cases: {len(failed)}")
print(f"Total entries in file: {len(data)}")
# Out:
# Successfully extracted: 87
# Failed cases: 0
# Total entries in file: 87

# %% [markdown]
# EXTRACTING ENTITIES FROM MAINTENANCE LOGS

# %%
# Extracting Entity from Machine Manual Books

import os
import base64

image_folder = "/Users/wbm/Documents/BIT/Research Topics/Potential Datasets/Manual Book/Images"
output = {}

# Sort filenames to keep them in page order
image_files = sorted([
    f for f in os.listdir(image_folder)
    if f.lower().endswith(('.jpg', '.jpeg', '.png'))
])

for img_file in image_files:
    img_path = os.path.join(image_folder, img_file)
    with open(img_path, "rb") as f:
        img_bytes = f.read()
    img_b64 = base64.b64encode(img_bytes).decode("utf-8")
    output[img_file] = img_b64
    print(f"Encoded: {img_file}")
# Out:
# Encoded: Compressor_9600_Brooks-images-0.jpg
# Encoded: Compressor_9600_Brooks-images-1.jpg
# Encoded: Cryopump_Brooks_Installation and Maintenance_001.jpg
# Encoded: Cryopump_Brooks_Installation and Maintenance_002.jpg
# Encoded: Helix_On-Board controller-2_page-0001.jpg
# Encoded: Helix_On-Board controller-2_page-0002.jpg
# Encoded: Ion Beam Drive-images-0.jpg
# Encoded: Ion Beam Drive-images-1.jpg
# Encoded: Ion Beam Drive-images-2.jpg
# Encoded: Ion Beam Drive-images-3.jpg
# Encoded: Ion Beam Drive-images-4.jpg

# %%
import os
import base64
import time
import json
from baml_client.sync_client import b
from baml_py import Image

# Configuration
image_folder = "/Users/wbm/Documents/BIT/Research Topics/Potential Datasets/Manual Book/Images"
output_path = "manual_book_fault_reports.json"
max_retries = 3
retry_delay = 30  # seconds

# Get image list
image_files = sorted([
    f for f in os.listdir(image_folder)
    if f.lower().endswith(('.jpg', '.jpeg', '.png'))
])

all_faults = []

def extract_with_retry(img_obj, image_name, retries=max_retries, delay=retry_delay):
    for attempt in range(retries):
        try:
            return b.ExtractFaultsFromImage(img=img_obj)
        except Exception as e:
            error_str = str(e).lower()
            if any(keyword in error_str for keyword in [
                "rate limit", 
                "context_length_exceeded", 
                "bad mac", 
                "token", 
                "context length", 
                "request failed"
            ]) and attempt < retries - 1:
                print(f" Error with {image_name}: {e}")
                print(f" Waiting {delay}s before retrying (attempt {attempt+1}/{retries})...")
                time.sleep(delay)
            else:
                print(f" Giving up on {image_name} after {attempt+1} attempt(s).\n")
                return []
            

# Main loop
for image_name in image_files:
    img_path = os.path.join(image_folder, image_name)
    print(f"\n🔍 Processing: {image_name}")
    
    try:
        # Load and encode
        with open(img_path, "rb") as f:
            img_bytes = f.read()
        img_b64 = base64.b64encode(img_bytes).decode("utf-8")
        img_obj = Image.from_base64("image/jpeg", img_b64)

        # Extract faults
        results = extract_with_retry(img_obj, image_name)

        # Append results with image source tag
        for fault in results:
            fault_dict = fault.model_dump()
            fault_dict["source_image"] = image_name
            all_faults.append(fault_dict)

    except Exception as e:
        print(f"Unhandled error on {image_name}: {e}")
# Out:
# 🔍 Processing: Compressor_9600_Brooks-images-0.jpg
# 2025-04-25T15:44:15.218 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 20875ms. StopReason: stop. Tokens(in/out): 1219/455
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective
# 🔍 Processing: Compressor_9600_Brooks-images-1.jpg
#  action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) trips immediately to the OFF (0) position when switched to the ON (1) position."
#         ],
#         "fault_reason": [
#           {
#             "name": "Incorrect phasing of input power."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check phasing of input power. Refer to 'Phase Check' in 'Section 3 - Installation'."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System (CB1) and Control Circuit (CB2) circuit breakers remain in the ON (1) position when switched ON but the compressor will not run."
#         ],
#         "fault_reason": [
#           {
#             "name": "No power coming from source."
#           },
#           {
#             "name": "Insufficient power."
#           },
#           {
#             "name": "Remote control jumper plug not in place. This will apply only if remote circuit is not being used."
#           },
#           {
#             "name": "Improperly wired external remote control circuit. NOTE: Only applies if remote control feature is being used."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check source fuses, circuit breakers, and wiring associated with the power source. Repair as needed."
#           },
#           {
#             "description": "Verify adequate phase-to-phase input voltage. Refer to Table 1-2."
#           },
#           {
#             "description": "Check to insure that remote jumper plug is fully seated. See Figure 1-4 for location. Refer to 'Compressor Remote Connector' in 'Section 1 - 9600 Compressor Description' for more information."
#           },
#           {
#             "description": "Verify correct installation of remote control feature. Refer to Table 1-6."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class FaultReport>)---
#     [
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) trips immediately to the OFF (0) position when switched to the ON (1) position."
#         ],
#         "fault_reason": [
#           {
#             "name": "Incorrect phasing of input power."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check phasing of input power. Refer to 'Phase Check' in 'Section 3 - Installation'."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System (CB1) and Control Circuit (CB2) circuit breakers remain in the ON (1) position when switched ON but the compressor will not run."
#         ],
#         "fault_reason": [
#           {
#             "name": "No power coming from source."
#           },
#           {
#             "name": "Insufficient power."
#           },
#           {
#             "name": "Remote control jumper plug not in place. This will apply only if remote circuit is not being used."
#           },
#           {
#             "name": "Improperly wired external remote control circuit. NOTE: Only applies if remote control feature is being used."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check source fuses, circuit breakers, and wiring associated with the power source. Repair as needed."
#           },
#           {
#             "description": "Verify adequate phase-to-phase input voltage. Refer to Table 1-2."
#           },
#           {
#             "description": "Check to insure that remote jumper plug is fully seated. See Figure 1-4 for location. Refer to 'Compressor Remote Connector' in 'Section 1 - 9600 Compressor Description' for more information."
#           },
#           {
#             "description": "Verify correct installation of remote control feature. Refer to Table 1-6."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
# 2025-04-25T15:44:34.367 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 19131ms. StopReason: stop. Tokens(in/out): 1219/610
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective
# 🔍 Processing: Cryopump_Brooks_Installation and Maintenance_001.jpg
#  action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) will not remain in the ON (1) position when switched ON.",
#           "Control Circuit circuit breaker (CB2) trips when excessive current is being drawn by the cold head or 24 volt compressor control circuits."
#         ],
#         "fault_reason": [
#           {
#             "name": "Damaged On-Board power cable, connectors, or drive motor."
#           },
#           {
#             "name": "Damaged component in the compressor power or control circuit."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check for compressor operation with cryopump cable disconnected from compressor. Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center if the compressor operates improperly."
#           },
#           {
#             "description": "Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) remains in the ON (1) position and the compressor stops after several minutes of operation and remains OFF (0)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Thermal protective switches are open."
#           },
#           {
#             "name": "Very cold water has caused a restriction of oil flow through the oil injection orifice during start-up."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check for inadequate water cooling. Refer to Table 1-3."
#           },
#           {
#             "description": "Recheck for proper cooling water temperature. Refer to Table 1-3. Restart compressor repeatedly until continuous operation is achieved."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) trips after a period of running."
#         ],
#         "fault_reason": [
#           {
#             "name": "Loss or degradation of power from the source."
#           },
#           {
#             "name": "Defective motor windings."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check that line voltage is correct on all phases."
#           },
#           {
#             "description": "Check running current on all phases."
#           },
#           {
#             "description": "Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the local Customer Support Center."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class FaultReport>)---
#     [
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) will not remain in the ON (1) position when switched ON.",
#           "Control Circuit circuit breaker (CB2) trips when excessive current is being drawn by the cold head or 24 volt compressor control circuits."
#         ],
#         "fault_reason": [
#           {
#             "name": "Damaged On-Board power cable, connectors, or drive motor."
#           },
#           {
#             "name": "Damaged component in the compressor power or control circuit."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check for compressor operation with cryopump cable disconnected from compressor. Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center if the compressor operates improperly."
#           },
#           {
#             "description": "Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) remains in the ON (1) position and the compressor stops after several minutes of operation and remains OFF (0)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Thermal protective switches are open."
#           },
#           {
#             "name": "Very cold water has caused a restriction of oil flow through the oil injection orifice during start-up."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check for inadequate water cooling. Refer to Table 1-3."
#           },
#           {
#             "description": "Recheck for proper cooling water temperature. Refer to Table 1-3. Restart compressor repeatedly until continuous operation is achieved."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Compressor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "System circuit breaker (CB1) trips after a period of running."
#         ],
#         "fault_reason": [
#           {
#             "name": "Loss or degradation of power from the source."
#           },
#           {
#             "name": "Defective motor windings."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check that line voltage is correct on all phases."
#           },
#           {
#             "description": "Check running current on all phases."
#           },
#           {
#             "description": "Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the local Customer Support Center."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#
# 🔍 Processing: Cryopump_Brooks_Installation and Maintenance_002.jpg2025-04-25T15:45:16.235 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 41847ms. StopReason: stop. Tokens(in/out): 1219/910
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective
#  action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature below 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "Air-to-vacuum leak in vacuum system or in cryopump."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check cryopump relief valve for proper seating."
#           },
#           {
#             "description": "Check cryopump for leaks."
#           },
#           {
#             "description": "Check vacuum chamber and Hi-Vac valve for leaks."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature below 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "High partial pressure of noncondensables (helium, hydrogen, or neon) within the cryopump because the 15K array has reached full capacity."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Regenerate the cryopump as described in the appropriate On-Board Cryopump Module Programming and Operation Instructions (8040410)."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature below 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "One of the arrays is loose, thereby preventing good thermal contact with its cold station on the cold head."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Warm the cryopump to ambient temperature, and retighten the arrays to 15-20 inch/pounds."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature above 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "Decrease in cryopump cold head performance."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "If the helium return pressure gauge reads below the normal operating return pressure 100-120 psig (690-827 kPa), add gas as described in the appropriate compressor manual."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature above 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "High partial pressure of non-condensables (helium, hydrogen, or neon) within the cryopump because the 15K array has reached full capacity."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Regenerate the cryopump as described in the appropriate On-Board Cryopump Module Programming and Operation Instructions (8040410)."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature above 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "Excessive thermal load on frontal array."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Reduce the thermal radiation load by 1) shielding the cryopump or 2) lowering the temperature of the radiating surface."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class FaultReport>)---
#     [
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature below 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "Air-to-vacuum leak in vacuum system or in cryopump."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check cryopump relief valve for proper seating."
#           },
#           {
#             "description": "Check cryopump for leaks."
#           },
#           {
#             "description": "Check vacuum chamber and Hi-Vac valve for leaks."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature below 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "High partial pressure of noncondensables (helium, hydrogen, or neon) within the cryopump because the 15K array has reached full capacity."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Regenerate the cryopump as described in the appropriate On-Board Cryopump Module Programming and Operation Instructions (8040410)."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature below 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "One of the arrays is loose, thereby preventing good thermal contact with its cold station on the cold head."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Warm the cryopump to ambient temperature, and retighten the arrays to 15-20 inch/pounds."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature above 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "Decrease in cryopump cold head performance."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "If the helium return pressure gauge reads below the normal operating return pressure 100-120 psig (690-827 kPa), add gas as described in the appropriate compressor manual."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature above 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "High partial pressure of non-condensables (helium, hydrogen, or neon) within the cryopump because the 15K array has reached full capacity."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Regenerate the cryopump as described in the appropriate On-Board Cryopump Module Programming and Operation Instructions (8040410)."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "High base pressure of vacuum system",
#           "Cryopump temperature above 20K"
#         ],
#         "fault_reason": [
#           {
#             "name": "Excessive thermal load on frontal array."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Reduce the thermal radiation load by 1) shielding the cryopump or 2) lowering the temperature of the radiating surface."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#
# 🔍 Processing: Helix_On-Board controller-2_page-0001.jpg2025-04-25T15:45:51.275 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 35018ms. StopReason: stop. Tokens(in/out): 1219/950
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Low helium supply pressure."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Add gas as described in the appropriate compressor manual."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Compressor problems."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Refer to the appropriate compressor manual."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Leak in vacuum system or cryopump."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check the cryopump relief valve for proper seating."
#           },
#           {
#             "description": "Check cryopump for leaks."
#           },
#           {
#             "description": "Check vacuum system for leaks."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Incomplete regeneration may not have fully cleaned the adsorbing array. Partial pressures of non-condensables (hydrogen, neon or helium) may remain."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Regenerate the cryopump as described in the appropriate On-Board Cryopump Module Programming and Operation Instructions (8040410)."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "No display."
#         ],
#         "fault_reason": [
#           {
#             "name": "No power to On-Board cryopump."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check electrical connections; be sure the power switch at the compressor controller is turned on. Check fuses. If power is turned on, try turning it off and on to reboot the electronics. Change electronics module."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Display does not update, and/or keys do not function."
#         ],
#         "fault_reason": [
#           {
#             "name": "Electronics has locked up."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Try to reboot the system by turning the On-Board power switch located at the compressor controller off and on. Replace the On-Board electronic module."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Rough valve clicks but does not open and close."
#         ],
#         "fault_reason": [
#           {
#             "name": "Too little or no air pressure to drive valve."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Increase air pressure to 60 psig minimum, 80 psig maximum."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class FaultReport>)---
#     [
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Low helium supply pressure."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Add gas as described in the appropriate compressor manual."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Compressor problems."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Refer to the appropriate compressor manual."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Leak in vacuum system or cryopump."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check the cryopump relief valve for proper seating."
#           },
#           {
#             "description": "Check cryopump for leaks."
#           },
#           {
#             "description": "Check vacuum system for leaks."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Cryopump fails to cool down to the required operating temperature or takes too long to reach that temperature (20K)."
#         ],
#         "fault_reason": [
#           {
#             "name": "Incomplete regeneration may not have fully cleaned the adsorbing array. Partial pressures of non-condensables (hydrogen, neon or helium) may remain."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Regenerate the cryopump as described in the appropriate On-Board Cryopump Module Programming and Operation Instructions (8040410)."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "No display."
#         ],
#         "fault_reason": [
#           {
#             "name": "No power to On-Board cryopump."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check electrical connections; be sure the power switch at the compressor controller is turned on. Check fuses. If power is turned on, try turning it off and on to reboot the electronics. Change electronics module."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Display does not update, and/or keys do not function."
#         ],
#         "fault_reason": [
#           {
#             "name": "Electronics has locked up."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Try to reboot the system by turning the On-Board power switch located at the compressor controller off and on. Replace the On-Board electronic module."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Cryopump",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Rough valve clicks but does not open and close."
#         ],
#         "fault_reason": [
#           {
#             "name": "Too little or no air pressure to drive valve."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Increase air pressure to 60 psig minimum, 80 psig maximum."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#
# 2025-04-25T15:46:00.792 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 9504ms. StopReason: stop. Tokens(in/out): 1219/227
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective
# 🔍 Processing: Helix_On-Board controller-2_page-0002.jpg
# action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Helix Intercomponent Network",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "On-Board IS Cryopumps are not visible on IS Controller screens."
#         ],
#         "fault_reason": [
#           {
#             "name": "A network terminator is not installed in the last cryopump on channel A or B."
#           },
#           {
#             "name": "The cryopump is connected to channel C."
#           },
#           {
#             "name": "Defective network cable."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Refer to the On-Board IS Cryopump Quick Installation Guide and install a network terminator in the last cryopump on channels A or B."
#           },
#           {
#             "description": "Disconnect the cryopump from channel C and connect it to channels A or B."
#           },
#           {
#             "description": "Replace network cable."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class FaultReport>)---
#     [
#       {
#         "fault_location": {
#           "name": "Helix Intercomponent Network",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "On-Board IS Cryopumps are not visible on IS Controller screens."
#         ],
#         "fault_reason": [
#           {
#             "name": "A network terminator is not installed in the last cryopump on channel A or B."
#           },
#           {
#             "name": "The cryopump is connected to channel C."
#           },
#           {
#             "name": "Defective network cable."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Refer to the On-Board IS Cryopump Quick Installation Guide and install a network terminator in the last cryopump on channels A or B."
#           },
#           {
#             "description": "Disconnect the cryopump from channel C and connect it to channels A or B."
#           },
#           {
#             "description": "Replace network cable."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#  Giving up on Helix_On-Board controller-2_page-0002.jpg after 1 attempt(s).
# 2025-04-25T15:46:01.048 [BAML WARN] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (<unknown>) - 249ms
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective action(s) from the same row in the `Corrective Action
#
# 🔍 Processing: Ion Beam Drive-images-0.jpg
# ` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---REQUEST OPTIONS---
#     model: "gpt-4o"
#     temperature: 0
#     ---ERROR (Unspecified error code: 2)---
#     reqwest::Error { kind: Request, url: "https://api.openai.com/v1/chat/completions", source: hyper_util::client::legacy::Error(SendRequest, hyper::Error(Io, Custom { kind: BrokenPipe, error: "stream closed because of a broken pipe" })) }
# 2025-04-25T15:46:24.349 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 23290ms. StopReason: stop. Tokens(in/out): 1219/718
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective
# 🔍 Processing: Ion Beam Drive-images-1.jpg
#  action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Auxiliary Contactor",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Auxiliary contactor won’t close (you should be able to hear it close)."
#         ],
#         "fault_reason": [
#           {
#             "name": "ID is not plugged in."
#           },
#           {
#             "name": "Circuit breaker on the rear panel is tripped."
#           },
#           {
#             "name": "Fuses F1 and F2 on the left chassis board inside the power supply are blown."
#           },
#           {
#             "name": "Loose connectors."
#           }
#         ],
#         "fault_measures": [
#           {
# ...
#           },
#           {
#             "name": "Fault switch settings"
#           },
#           {
#             "name": "Neon not on"
#           },
#           {
#             "name": "Blown fuse"
#           },
#           {
#             "name": "Improper connector contact"
#           },
#           {
#             "name": "Bent or damaged pins"
#           },
#           {
#             "name": "Improper installation of connectors"
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check the cathode or neutralizer filaments"
#           },
#           {
#             "description": "Set the CATHODE FAULT switch to DISABLE and the NEUTRALIZER FAULT switch to position 2"
#           },
#           {
#             "description": "Turn the POWER switch ON and the SOURCE switch ON"
#           },
#           {
#             "description": "Check the neon on the module associated with the flashing LED"
#           },
#           {
#             "description": "If the neon is not on, turn the POWER switch to OFF"
#           },
#           {
#             "description": "Discharge the bus capacitor"
#           },
#           {
#             "description": "Check fuses F1 and F2 on the module associated with the flashing status LED"
#           },
#           {
#             "description": "Replace any blown fuse with the same size fuse"
#           },
#           {
#             "description": "Check the center connector on the inverter module for proper connection"
#           },
#           {
#             "description": "Check for bent or damaged pins"
#           },
#           {
#             "description": "Re-install the module, making certain of proper contact of all connectors"
#           },
#           {
#             "description": "Check for proper installation of the connectors on the output terminal board TB1"
#           },
#           {
#             "description": "If proper connection is made, remove the connector associated with the flashing LED and check for continuity back through the cable and into your system"
#           },
#           {
#             "description": "Re-install the connector"
#           },
#           {
#             "description": "Return the fault switches to the normal operating positions before running the unit"
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#
# 2025-04-25T15:47:35.823 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 19137ms. StopReason: stop. Tokens(in/out): 1219/489
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective
# 🔍 Processing: Ion Beam Drive-images-4.jpg
#  action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Inverter",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Bus contactor closes and normal front panel displays work, but there is no discharge inverter output."
#         ],
#         "fault_reason": [
#           {
#             "name": "No voltage due to a short in the system between the anode and cathode."
#           },
#           {
#             "name": "No current or voltage due to incorrect power or source switch settings."
#           },
#           {
#             "name": "Neon not on due to issues in the discharge module."
#           },
#           {
#             "name": "Blown fuses F1 and F2 on the discharge module."
#           },
#           {
#             "name": "Improper connection of the center connector on the inverter module."
#           },
#           {
#             "name": "Bent or damaged pins in the module."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check the discharge current and voltage on the front panel."
#           },
#           {
#             "description": "Check the gas flow into the ion source."
#           },
#           {
#             "description": "If there is current and gas flow, but no voltage, check for a short in your system between the anode and cathode."
#           },
#           {
#             "description": "If there is gas flow, but no current or voltage, turn the POWER switch to ON and the SOURCE switch to ON."
#           },
#           {
#             "description": "Check the neon on the discharge module."
#           },
#           {
#             "description": "If the neon is not on, turn the POWER switch to OFF. Turn the power going into the ID off."
#           },
#           {
#             "description": "Discharge the bus capacitor."
#           },
#           {
#             "description": "Check fuses F1 and F2 on the discharge module. Replace any blown fuse with the same size fuse."
#           },
#           {
#             "description": "If the fuses are good, check the center connector on the inverter module for proper connection."
#           },
#           {
#             "description": "Check for bent or damaged pins."
#           },
#           {
#             "description": "Re-install the module, making certain of proper contact of all connectors."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class FaultReport>)---
#     [
#       {
#         "fault_location": {
#           "name": "Inverter",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Bus contactor closes and normal front panel displays work, but there is no discharge inverter output."
#         ],
#         "fault_reason": [
#           {
#             "name": "No voltage due to a short in the system between the anode and cathode."
#           },
#           {
#             "name": "No current or voltage due to incorrect power or source switch settings."
#           },
#           {
#             "name": "Neon not on due to issues in the discharge module."
#           },
#           {
#             "name": "Blown fuses F1 and F2 on the discharge module."
#           },
#           {
#             "name": "Improper connection of the center connector on the inverter module."
#           },
#           {
#             "name": "Bent or damaged pins in the module."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Check the discharge current and voltage on the front panel."
#           },
#           {
#             "description": "Check the gas flow into the ion source."
#           },
#           {
#             "description": "If there is current and gas flow, but no voltage, check for a short in your system between the anode and cathode."
#           },
#           {
#             "description": "If there is gas flow, but no current or voltage, turn the POWER switch to ON and the SOURCE switch to ON."
#           },
#           {
#             "description": "Check the neon on the discharge module."
#           },
#           {
#             "description": "If the neon is not on, turn the POWER switch to OFF. Turn the power going into the ID off."
#           },
#           {
#             "description": "Discharge the bus capacitor."
#           },
#           {
#             "description": "Check fuses F1 and F2 on the discharge module. Replace any blown fuse with the same size fuse."
#           },
#           {
#             "description": "If the fuses are good, check the center connector on the inverter module for proper connection."
#           },
#           {
#             "description": "Check for bent or damaged pins."
#           },
#           {
#             "description": "Re-install the module, making certain of proper contact of all connectors."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
# 2025-04-25T15:47:48.726 [BAML INFO] Function ExtractFaultsFromImage:
#     Client: CustomGPT4o (gpt-4o-2024-08-06) - 12890ms. StopReason: stop. Tokens(in/out): 1219/413
#     ---PROMPT---
#     system: You are an expert in industrial machine maintenance and repair.
#
#     The following image is a troubleshooting table. Your task is to extract all distinct fault cases.
#
#     **Important rules**:
#     - The overall component/system being diagnosed (e.g., from the table title like “Compressor Troubleshooting Procedures”) should be used as the **fault_location**, unless a more specific subcomponent is clearly the root of the issue.
#     - If no machine (IBM3 or IBM4) is mentioned in the image, omit it from the output.
#     - Do NOT use the component mentioned in the symptom (e.g., a breaker or connector) as the fault location unless it is clearly the root cause.
#     - For each `fault_reason`, also extract the **corresponding** corrective action(s) from the same row in the `Corrective Action` or other relevant column as `fault_measures`.
#     - Only assign measures that are **explicitly linked** to the given reason (typically matched by the same number from the same row, e.g., Reason 2 → Measure 2 or usually from the same row). Do not merge unrelated measures across multiple causes.
#     - Do not output any visual separators, numbering (e.g., "1.", "2.", "🔧 Fault 1", "Fault 2", etc.). Only extract the clean textual content of each field (symptoms, reasons, measures).
#
#     For each fault, extract:
#     - `fault_location`: the major component (usually from the table title)
#     - `fault_symptoms`: what problem is observed
#     - `fault_reason`: possible causes listed
#     - `fault_measures`: corrective actions listed
#     - `resolution_status`: if stated; otherwise, omit
#
#     Return a valid JSON array of FaultReport objects.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         fault_location: {
#           name: string,
#           machine: 'IBM3' or 'IBM4' or null,
#         },
#         fault_symptoms: string[],
#         fault_reason: [
#           {
#             name: string,
#           }
#         ],
#         fault_measures: [
#           {
#             description: string,
#           }
#         ],
#         resolution_status: 'Resolved' or 'Unknown',
#       }
#     ]
#     user: <image_placeholder base64>
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "fault_location": {
#           "name": "Inverter Module",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "No control of, or output from, an inverter module."
#         ],
#         "fault_reason": [
#           {
#             "name": "Possible issues with power supply, fuses, or connections."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Try operating the supply in manual mode. With the POWER switch set to ON and the SOURCE switch set to ON, check the neon on the module associated with the flashing LED. If the neon is not on, turn the POWER switch OFF. Turn the power going into the ID off. Discharge the bus capacitor. Check fuses F1 and F2 on the module associated with the flashing status LED. Replace any blown fuse with the same size fuse. If the fuses are good, check the center connector on the inverter module for proper connection. Check for bent or damaged pins. Re-install the module carefully — making certain of proper pin alignment — and replace the board. Install the plastic and metal covers and check operation. If the fuse blows again, replace the entire board. Before installing a new board make certain all pins are straight so that proper contact can be made."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Inverter Module",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Unit running, but not functioning as expected."
#         ],
#         "fault_reason": [
#           {
#             "name": "Unknown operational issue."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Record all present parameter values, and obtain normal operating parameter values. Record the condition of the DS1 LEDs on the inverter boards, then call AE Customer Service."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class FaultReport>)---
#     [
#       {
#         "fault_location": {
#           "name": "Inverter Module",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "No control of, or output from, an inverter module."
#         ],
#         "fault_reason": [
#           {
#             "name": "Possible issues with power supply, fuses, or connections."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Try operating the supply in manual mode. With the POWER switch set to ON and the SOURCE switch set to ON, check the neon on the module associated with the flashing LED. If the neon is not on, turn the POWER switch OFF. Turn the power going into the ID off. Discharge the bus capacitor. Check fuses F1 and F2 on the module associated with the flashing status LED. Replace any blown fuse with the same size fuse. If the fuses are good, check the center connector on the inverter module for proper connection. Check for bent or damaged pins. Re-install the module carefully — making certain of proper pin alignment — and replace the board. Install the plastic and metal covers and check operation. If the fuse blows again, replace the entire board. Before installing a new board make certain all pins are straight so that proper contact can be made."
#           }
#         ],
#         "resolution_status": "Unknown"
#       },
#       {
#         "fault_location": {
#           "name": "Inverter Module",
#           "machine": null
#         },
#         "fault_symptoms": [
#           "Unit running, but not functioning as expected."
#         ],
#         "fault_reason": [
#           {
#             "name": "Unknown operational issue."
#           }
#         ],
#         "fault_measures": [
#           {
#             "description": "Record all present parameter values, and obtain normal operating parameter values. Record the condition of the DS1 LEDs on the inverter boards, then call AE Customer Service."
#           }
#         ],
#         "resolution_status": "Unknown"
#       }
#     ]

# %%
# Save everything
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(all_faults, f, indent=2, ensure_ascii=False)

print(f"\n Done! Extracted {len(all_faults)} faults from {len(image_files)} images → {output_path}")
# Out:
#  Done! Extracted 28 faults from 11 images → manual_book_fault_reports.json
