# %%
import os
from neo4j import GraphDatabase
from dotenv import load_dotenv

# %%
# Load .env variables
load_dotenv()

# Read environment variables
uri = os.getenv("NEO4J_URI")
user = os.getenv("NEO4J_USER")
pwd = os.getenv("NEO4J_PASS")

# Create Neo4j driver
driver = GraphDatabase.driver(uri, auth=(user, pwd))

# Test connection
try:
    with driver.session() as session:
        result = session.run("RETURN 1 AS test").single()
        print("Connected to Neo4j! Test query returned:", result["test"])
except Exception as e:
    print("Connection failed:", e)
# Out:
# Connected to Neo4j! Test query returned: 1

# %% [markdown]
# Install neo4j package for graphrag
#
# pip install neo4j-graphrag

# %%
# Setting up OpenAI Embeddings

import os
from dotenv import load_dotenv

# Load the .env file
load_dotenv()

# Force-set the key into the environment in case it's still not picked up
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

from neo4j_graphrag.embeddings import OpenAIEmbeddings
embedder = OpenAIEmbeddings(model="text-embedding-ada-002")

# %% [markdown]
# STEP 1 : Tagging Nodes for Indexing
#
# Add new label for all entities "TextChunk"
#
# this is the cypher to do that in Neo4J
#
# MATCH (n:FaultSymptom) SET n:TextChunk;
# MATCH (n:FaultReason) SET n:TextChunk;
# MATCH (n:FaultMeasure) SET n:TextChunk;
# MATCH (n:FaultLocation) SET n:TextChunk;
#
# it is not changing the existing label, but it add new ones "TextChunk" for each entity

# %%
# Step 2: Creating a Vector Index in Neo4j

from neo4j_graphrag.indexes import create_vector_index

driver = GraphDatabase.driver(uri, auth=(user, pwd))

INDEX_NAME = "content_index"
label_to_index = "TextChunk"
vector_prop = "embedding"
dim = 1536

# Create vector index (once only)
create_vector_index(
    driver,
    INDEX_NAME,
    label=label_to_index,
    embedding_property=vector_prop,
    dimensions=dim,
    similarity_fn="cosine"  # cosine is best for OpenAI embeddings
)

print(f"Vector index '{INDEX_NAME}' created successfully.")
# Out:
# Vector index 'content_index' created successfully.

# %%
# Step 3: Computing and Upserting Embeddings

from neo4j_graphrag.embeddings import OpenAIEmbeddings
from neo4j_graphrag.indexes import upsert_vectors
from neo4j_graphrag.types import EntityType

# Initialize embedder (you previously set OPENAI_API_KEY)
embedder = OpenAIEmbeddings(model="text-embedding-ada-002")

# Query adjusted for your property names
query = """
MATCH (n:TextChunk)
WHERE (n:FaultSymptom AND n.description IS NOT NULL)
   OR (n:FaultMeasure AND n.description IS NOT NULL)
   OR (n:FaultReason AND n.name IS NOT NULL)
   OR (n:FaultLocation AND n.name IS NOT NULL)
RETURN elementId(n) AS node_id,
       CASE
         WHEN n:FaultSymptom THEN n.description
         WHEN n:FaultMeasure THEN n.description
         WHEN n:FaultReason THEN n.name
         WHEN n:FaultLocation THEN n.name
       END AS content
"""

with driver.session() as session:
    result = session.run(query)
    records = result.data()

print(f"Found {len(records)} nodes to embed.")
# Out:
# Found 740 nodes to embed.

# %% [markdown]
# Example format of the output for records:
#
# {
#   "node_id": "some_id",
#   "content": "The vacuum pump overheats when running continuously"
# }

# %%
# Compute Embeddings

node_ids = []
embeddings = []

for record in records:
    text = record["content"]
    node_id = record["node_id"]

    #Safety check in case of empty texts
    if not text or not text.strip():
        continue

    vec = embedder.embed_query(text)

    node_ids.append(str(node_id))
    embeddings.append(vec)

print(f"Generated embeddings for {len(node_ids)} nodes.")
# Out:
# Generated embeddings for 740 nodes.

# %%
# Upsert embeddings to Neo4J

upsert_vectors(
    driver,
    ids=node_ids,
    embedding_property= "embedding",
    embeddings=embeddings,
    entity_type=EntityType.NODE
)

print(f" Indexed {len(node_ids)} text nodes with embeddings.")
# Out:
#  Indexed 740 text nodes with embeddings.

# %% [markdown]
# Implementing Retrieval Strategies (Vector Search and Text-to-Cypher)

# %%
from neo4j_graphrag.llm import OpenAILLM

# Instantiate the LLM for generating answers
llm = OpenAILLM(
    model_name="gpt-3.5-turbo",
    model_params={"temperature":0, "max_tokens": 1024}
)

# %% [markdown]
# Internally, Neo4J uses Langchain

# %%
# VectorRetriever - Semantic Vector Search

from neo4j_graphrag.retrievers import VectorRetriever

vector_retriever = VectorRetriever(driver, INDEX_NAME, embedder)

# %% [markdown]
# By default, this retriever will just retrieve the node and its similarity score
# neo4j.com
# . Often, you might want not just the raw node but some surrounding context. For example, if a log entry node is found, maybe you want to pull its related equipment or location. The GraphRAG library offers a VectorCypherRetriever which allows a follow-up Cypher query using the found node as a starting point
# neo4j
#
# Later, this might be useful for finding the FaultLocation is belong to which type_of components in Machine Ontology.

# %%
# Text2CypherRetriever - NL to Cypher Querying

from neo4j_graphrag.retrievers import Text2CypherRetriever

neo4j_schema = """
Graph schema:
- Nodes: [FaultSymptom, FaultReason, FaultMeasure, FaultLocation]
- Relationships:
  (FaultSymptom)-[:CAUSED_BY]->(FaultReason)
  (FaultSymptom)-[:MITIGATED_BY {resolution_status}]->(FaultMeasure)
  (FaultLocation)-[:HAS_FAULT]->(FaultSymptom)
- Properties:
  FaultSymptom{description}
  FaultReason{name}
  FaultMeasure{description}
  FaultLocation{name, machines}
"""

examples = [
        "Q: What fault symptoms are associated with cryopump?\nCypher: MATCH (fl:FaultLocation)-[:HAS_FAULT]->(fs:FaultSymptom) WHERE toLower(fl.name) = 'compressor' RETURN fs.description",
        "Q: De neutralizer heeft geen emissie. Wat zijn de mogelijke oorzaken?\n MATCH (fl:FaultLocation)-[hf:HAS_FAULT]->(fs:FaultSymptom)-[cb:CAUSED_BY]->(fr:FaultReason) WHERE fl.name = 'Neutralizer' AND toLower(fs.description) CONTAINS 'geen emissie' RETURN fr",
        "Q: Welke maatregel moet worden genomen als er lucht terugkomt in het koelcircuit en er lekkage is bij de glycolpomp?\n MATCH (fl:FaultLocation)-[hf:HAS_FAULT]->(fs:FaultSymptom)-[mb:MITIGATED_BY]->(fm:FaultMeasure) WHERE fl.name = 'Glycolpomp' AND (fs.description CONTAINS 'lekkage' OR fs.description CONTAINS 'lucht') RETURN fm"
    ]    

t2c_llm = OpenAILLM(model_name="gpt-3.5-turbo", model_params={"temperature": 0})
text2cypher_retriever = Text2CypherRetriever(
    driver=driver,
    llm=t2c_llm,
    neo4j_schema=neo4j_schema,
    examples= examples
)

# %% [markdown]
# CHATBOT PIPELINE

# %%
from langdetect import detect

def answer_question(query: str) -> str:
    # Automatically detect the language of the query
    try:
        language = detect(query)
        print(f"[DEBUG] Detected language: {language}")
    except Exception as e:
        print(f"[DEBUG] Language detection failed: {e}")
        language = "en"  # fallback if detection fails

    # Setup storage
    context_chunks = []
    answer_parts = []

    # Run text2cypher Retriever
    try:
        records = list(text2cypher_retriever.search(query))
    except Exception as e:
        records = []

    # Format Text2Cypher result
    if records:
        context_text = "Graph query results:\n"
        for rec in records:
            context_text += str(rec) + "\n"
        context_chunks.append(context_text)
        answer_parts.append(f"*Data retrieved from graph for the query.*")

    # Run vector retriever (semantic search)
    try:
        results = list(vector_retriever.search(query_text=query, top_k=10))
    except Exception as e:
         results = []

    # Format Vector Retriever Results
    if results:
        # Check if it's the ('items', [...]) pattern
        if results[0][0] == "items":
            retriever_items = results[0][1]  # this is the list of RetrieverResultItem
            for item in retriever_items:
                try:
                    # Parse the inner content
                    content = eval(item.content) if isinstance(item.content, str) else item.content
                    snippet = (
                        content.get("description") or
                        content.get("text") or
                        content.get("name") or
                        content.get("content") or
                        str(content)
                    )
                    score = item.metadata.get("score", 0.0)
                    context_chunks.append(f"Excerpt (score {score:.2f}): {snippet}")
                except Exception as parse_e:
                    context_chunks.append(f"(Parsing error: {parse_e}) Raw: {item}")
            answer_parts.append(f"*Found {len(retriever_items)} related documents in the knowledge base.*")
        else:
            # Fallback for unknown structure
            context_chunks.append("(Unknown result structure)")

    # Combine the context for LLM
    if context_chunks:
        context_str = "\n\n".join(context_chunks)
    else:
        context_str = "(No direct context found; rely on general knowledge.)"
    
    # LLM System Instruction (language-aware)
    system_msg = (
        "You are an assistant answering questions about maintenance and troubleshooting of machine."
        "Use the provided graph data to answer"
    )

    if language == "nl":
        system_msg += "Vertaal alle technische beschrijvingen naar het Nederlands. Antwoord volledig in het Nederlands."
    else:
        system_msg += "Translate all retrieved technical descriptions into English. Respond entirely in English."

    # Final prompt for the LLM
    prompt = f"{system_msg}\n\nContext:\n{context_str}\n\nQuestion: {query}\nAnswer:"

    print("===== FINAL PROMPT TO LLM =====")
    print(prompt)
    print("================================")

    #Generate the final answer using the LLM
    final_answer = llm.invoke(prompt)
    return final_answer

# %%
question = "Wat zijn de mogelijke foutsymptomen bij PLC's?"
answer = answer_question(question)
print(answer)
# Out:
# [DEBUG] Detected language: nl
# ===== FINAL PROMPT TO LLM =====
# You are an assistant answering questions about maintenance and troubleshooting of machine.Use the provided graph data to answerVertaal alle technische beschrijvingen naar het Nederlands. Antwoord volledig in het Nederlands.
#
# Context:
# Graph query results:
# ('items', [])
# ('metadata', {'cypher': "MATCH (fl:FaultLocation)-[:HAS_FAULT]->(fs:FaultSymptom) WHERE toLower(fl.name) = 'PLC' RETURN fs.description", '__retriever': 'Text2CypherRetriever'})
#
#
# Excerpt (score 0.93): problemen van de motor control lijken van de PLC/instellingen ARC-net kaart te komen
#
# Excerpt (score 0.93): tekening komt niet overeen met de PLC
#
# Excerpt (score 0.93): PLC / computer(?) Op tilt: tegenstrijdige foutmeldingen
#
# Excerpt (score 0.92): hardware in orde, problemen in de PLC/Arc-net kaart
#
# Excerpt (score 0.92): PLC kaart
#
# Question: Wat zijn de mogelijke foutsymptomen bij PLC's?
# Answer:
# ================================
# content="Mogelijke foutsymptomen bij PLC's kunnen zijn problemen met de motorbesturing, afwijkende tekeningen, foutmeldingen, hardwareproblemen en conflicterende foutmeldingen. Deze problemen kunnen worden veroorzaakt door de PLC-instellingen of de Arc-net kaart. Het is belangrijk om de PLC en de bijbehorende hardware grondig te controleren en eventuele fouten op te lossen."

# %%
question = "Wat zijn de mogelijke foutsymptomen bij een bron?"
answer = answer_question(question)
print(answer)
# Out:
# [DEBUG] Detected language: nl
# ===== FINAL PROMPT TO LLM =====
# You are an assistant answering questions about maintenance and troubleshooting of machine.Use the provided graph data to answerVertaal alle technische beschrijvingen naar het Nederlands. Antwoord volledig in het Nederlands.
#
# Context:
# Graph query results:
# ('items', [RetrieverResultItem(content="<Record fs.description='Bron startte niet door'>", metadata=None), RetrieverResultItem(content="<Record fs.description='emissie blijft vaak beperkt tot 24mA'>", metadata=None), RetrieverResultItem(content="<Record fs.description='oude probleem, geen bundel uit de bron'>", metadata=None), RetrieverResultItem(content="<Record fs.description='Uitval tijdens proces'>", metadata=None), RetrieverResultItem(content="<Record fs.description='communicatie fout'>", metadata=None), RetrieverResultItem(content='<Record fs.description=\'start in stand "plasma" niet door\'>', metadata=None)])
# ('metadata', {'cypher': "MATCH (fl:FaultLocation)-[:HAS_FAULT]->(fs:FaultSymptom) WHERE toLower(fl.name) = 'bron' RETURN fs.description", '__retriever': 'Text2CypherRetriever'})
#
#
# Excerpt (score 0.93): Piepgeluiden uit de bron
#
# Excerpt (score 0.92): Lijkt vaker op te treden als bron / machine warm is
#
# Excerpt (score 0.92): Mogelijke oorzaak was: geleiding over keramische isolatoren bij aansluiting op bron
#
# Excerpt (score 0.91): Spanning bron
#
# Excerpt (score 0.91): mogelijk door communicatie fout
#
# Excerpt (score 0.91): tegenstrijdige foutmeldingen
#
# Excerpt (score 0.91): Opstartproblemen
#
# Excerpt (score 0.91): He-lekkage aan de heatexchanger
#
# Excerpt (score 0.91): He-lekkage aan de heatexchanger
#
# Excerpt (score 0.91): Plasma bron starte niet op
#
# Question: Wat zijn de mogelijke foutsymptomen bij een bron?
# Answer:
# ================================
# content='Mogelijke foutsymptomen bij een bron zijn onder andere piepgeluiden, optreden van fouten wanneer de bron/machine warm is, geleiding over keramische isolatoren bij aansluiting op de bron, spanning problemen, communicatie fouten, tegenstrijdige foutmeldingen, opstartproblemen, lekkage aan de heatexchanger en het niet opstarten van de plasma bron.'

# %%
question = "Ik kan de plasma bron niet starten. Hoe komt dat en wat moet ik doen?"
answer = answer_question(question)
print(answer)
# Out:
# [DEBUG] Detected language: nl
# ===== FINAL PROMPT TO LLM =====
# You are an assistant answering questions about maintenance and troubleshooting of machine.Use the provided graph data to answerVertaal alle technische beschrijvingen naar het Nederlands. Antwoord volledig in het Nederlands.
#
# Context:
# Graph query results:
# ('items', [])
# ('metadata', {'cypher': "MATCH (fl:FaultLocation)-[:HAS_FAULT]->(fs:FaultSymptom)-[:CAUSED_BY]->(fr:FaultReason) WHERE toLower(fl.name) = 'plasma bron' AND toLower(fs.description) CONTAINS 'niet starten' RETURN fr", '__retriever': 'Text2CypherRetriever'})
#
#
# Excerpt (score 0.95): Plasma bron starte niet op
#
# Excerpt (score 0.92): start in stand "plasma" niet door
#
# Excerpt (score 0.92): machine start niet goed op
#
# Excerpt (score 0.92): blijkt hangen op status 'plasma'
#
# Excerpt (score 0.92): Opstartproblemen
#
# Excerpt (score 0.92): Neutralizer start niet goed op
#
# Excerpt (score 0.92): Machine geeft problemen met het opstarten
#
# Excerpt (score 0.92): Bij 135 mA viel bundel en plasma uit
#
# Excerpt (score 0.91): Neutralizer wilde niet starten
#
# Excerpt (score 0.91): Filamenten starten niet op
#
# Question: Ik kan de plasma bron niet starten. Hoe komt dat en wat moet ik doen?
# Answer:
# ================================
# content='Het feit dat de plasma bron niet start kan te maken hebben met verschillende redenen, zoals problemen met de opstartprocedure, problemen met de neutralizer of problemen met de filamenten. Om dit op te lossen, moet je eerst controleren of alle onderdelen correct zijn geïnstalleerd en goed functioneren. Controleer ook of er geen fouten zijn opgetreden tijdens het opstarten en of de machine correct is ingesteld. Als het probleem aanhoudt, is het raadzaam om een professionele technicus te raadplegen om het probleem te diagnosticeren en op te lossen.'

# %%
question = "Ik heb een probleem met de RF-generator. De plasmabron start niet. Hoe komt dat en wat is de oplossing?"
answer = answer_question(question)
print(answer)
# Out:
# [DEBUG] Detected language: nl
# ===== FINAL PROMPT TO LLM =====
# You are an assistant answering questions about maintenance and troubleshooting of machine.Use the provided graph data to answerVertaal alle technische beschrijvingen naar het Nederlands. Antwoord volledig in het Nederlands.
#
# Context:
# Graph query results:
# ('items', [])
# ('metadata', {'cypher': "MATCH (fl:FaultLocation)-[:HAS_FAULT]->(fs:FaultSymptom)-[:CAUSED_BY]->(fr:FaultReason) WHERE toLower(fl.name) = 'RF-generator' AND toLower(fs.description) CONTAINS 'plasmabron start niet' RETURN fr", '__retriever': 'Text2CypherRetriever'})
#
#
# Excerpt (score 0.93): Plasma bron starte niet op
#
# Excerpt (score 0.92): Machine geeft problemen met het opstarten
#
# Excerpt (score 0.92): Neutralizer start niet goed op
#
# Excerpt (score 0.92): machine start niet goed op
#
# Excerpt (score 0.92): Opstartproblemen
#
# Question: Ik heb een probleem met de RF-generator. De plasmabron start niet. Hoe komt dat en wat is de oplossing?
# Answer:
# ================================
# content='Het probleem met de RF-generator kan worden veroorzaakt door verschillende redenen, zoals een defect in de neutralizer of opstartproblemen. Om de exacte oorzaak te achterhalen en een oplossing te vinden, is het belangrijk om een grondige inspectie uit te voeren. Mogelijk moet de neutralizer worden gerepareerd of vervangen, of moeten er aanpassingen worden gedaan aan de opstartprocedure van de machine. Het is raadzaam om een professionele technicus in te schakelen om het probleem te diagnosticeren en op te lossen.'

# %%
question = "Ik heb een probleem met de compressor. het kan niet starten. Hoe komt dat en wat is de oplossing?"
answer = answer_question(question)
print(answer)
# Out:
# [DEBUG] Detected language: nl
# ===== FINAL PROMPT TO LLM =====
# You are an assistant answering questions about maintenance and troubleshooting of machine.Use the provided graph data to answerVertaal alle technische beschrijvingen naar het Nederlands. Antwoord volledig in het Nederlands.
#
# Context:
# Graph query results:
# ('items', [])
# ('metadata', {'cypher': "MATCH (fl:FaultLocation)-[:HAS_FAULT]->(fs:FaultSymptom)-[:CAUSED_BY]->(fr:FaultReason), (fl)-[:HAS_FAULT]->(fs)-[:MITIGATED_BY]->(fm:FaultMeasure) \nWHERE toLower(fl.name) = 'compressor' AND fs.description CONTAINS 'kan niet starten' \nRETURN fr.name, fm.description", '__retriever': 'Text2CypherRetriever'})
#
#
# Excerpt (score 0.93): Machine geeft problemen met het opstarten
#
# Excerpt (score 0.92): machine start niet goed op
#
# Excerpt (score 0.92): probleem met de koeling
#
# Excerpt (score 0.92): compressor had moeite met hoog vacuum
#
# Excerpt (score 0.92): Koelslangen omgewisseld en de compressor werkt weer
#
# Excerpt (score 0.92): Neutralizer start niet goed op
#
# Excerpt (score 0.92): Opstartproblemen
#
# Excerpt (score 0.92): Compressor problems.
#
# Excerpt (score 0.92): Tijdens regenereren valt de compressor uit
#
# Excerpt (score 0.92): vacuumproblemen
#
# Question: Ik heb een probleem met de compressor. het kan niet starten. Hoe komt dat en wat is de oplossing?
# Answer:
# ================================
# content='Het probleem met de compressor dat niet kan starten kan worden veroorzaakt door een aantal redenen, zoals problemen met de koeling of moeite met hoog vacuüm. Een mogelijke oplossing kan zijn om de koelslangen om te wisselen, zoals in een eerder geval waarbij de compressor weer werkte nadat dit was gedaan. Het kan ook helpen om de compressor te controleren tijdens het regenereren om te voorkomen dat deze uitvalt. Als het probleem aanhoudt, is het raadzaam om een professionele monteur te raadplegen voor verdere diagnose en reparatie.'

# %%
test_query = "Ik heb een probleem: de emissie van de Bron is beperkt tot 24mA. Wat zijn de mogelijke oorzaken van deze daling?"

items = text2cypher_retriever.search(test_query)

print(text2cypher_retriever.search(test_query))

print(items.metadata["cypher"])
# Out:
# items=[RetrieverResultItem(content="<Record fr=<Node element_id='4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:103' labels=frozenset({'TextChunk', 'FaultReason'}) properties={'name': 'Anode bleek een dikke harde isolerende laag te hebben', 'embedding': [0.008099883794784546, -0.010476883500814438, 0.0064237117767333984, -0.010793386027216911, -0.027826396748423576, 0.00803529191762209, 0.007286020088940859, -0.00323123368434608, -0.019028915092349052, -0.026508711278438568, 0.013809850439429283, 0.02808476611971855, 0.01924852840602398, 0.00775754451751709, -0.03841954469680786, -0.0008598860003985465, 0.04407783970236778, 0.02114754356443882, 0.0076219006441533566, 0.010722334496676922, -0.023731239140033722, 0.01213044859468937, -0.012886179611086845, -0.0076606557704508305, -0.003478299593552947, -0.017801659181714058, 0.007751085329800844, -0.026508711278438568, -0.012821586802601814, 0.0005215834244154394, 0.01330602914094925, -0.01834423467516899, -0.009960144758224487, -0.010774007998406887, -0.020165739580988884, 0.003011619672179222, -0.01357731781899929, 0.008784563280642033, 0.007951322011649609, 0.005855299066752195, 0.004085467662662268, -0.008403467945754528, 0.003985349554568529, -0.004951005801558495, -0.011691220104694366, 0.0014468692243099213, -0.02145758830010891, 0.020372435450553894, 0.0008316268213093281, 0.008558490313589573, 0.0249843318015337, -0.003279677825048566, -0.0004880761553067714, 0.001519535668194294, -0.014972512610256672, -0.01085151918232441, 0.0022381257731467485, -0.019158098846673965, -0.0067821997217834, -0.02608240209519863, -0.005978024564683437, -0.02515227161347866, -0.028523992747068405, 0.02190973423421383, -0.005047894082963467, -0.0013322177110239863, -0.02570776641368866, 0.011820404790341854, 0.01710406132042408, -0.007977158762514591, 0.02477763593196869, 0.008603704161942005, 0.010076411068439484, -0.005635684821754694, 0.007847974076867104, -0.005832691676914692, -0.0032538410741835833, -0.0003516247379593551, 0.027568025514483452, -0.000459816976217553, 0.017504533752799034, -0.014920839108526707, -0.014907920733094215, 0.023860424757003784, 0.028188113123178482, 0.025333130732178688, -0.002825916511937976, 0.011187399737536907, -0.017594963312149048, -0.007053487468510866, 0.006859710440039635, 0.03010004758834839, 0.029014894738793373, 0.015295474790036678, 0.008125720545649529, -0.004172667395323515, 0.0032215449027717113, 0.029531635344028473, -0.006449548993259668, -0.01209169253706932, -0.007376449648290873, -0.007014731876552105, -0.021612608805298805, -0.02632785215973854, -0.021883897483348846, 0.00943048670887947, 0.003257070668041706, 0.026392444968223572, 0.01703946851193905, -0.036016710102558136, 0.02847231924533844, 0.05451596528291702, 0.040615685284137726, -0.062318723648786545, -0.024209223687648773, -0.005467744544148445, -0.013628991320729256, -0.00941756833344698, -0.007163294591009617, -0.02038535475730896, 0.01809878461062908, 0.011135725304484367, 0.0032829076517373323, -0.02391209825873375, 0.01162662822753191, 0.02170303836464882, -0.041132424026727676, -0.03668846935033798, 0.023899178951978683, 0.008332416415214539, 0.024622613564133644, -0.003907838836312294, 0.014468692243099213, -0.0011553961085155606, -0.003163411747664213, 0.012614890933036804, -0.03526743873953819, 0.016419382765889168, 0.0023479328956454992, -0.02038535475730896, -0.003846476087346673, -0.0020750300027430058, -0.0039788903668522835, -0.015980154275894165, -0.00502851651981473, 0.018550930544734, -0.008455142378807068, 0.021780548617243767, 0.005238441750407219, -0.011484524235129356, -0.020126985386013985, -0.018215050920844078, 0.001794053241610527, -0.024131711572408676, 0.008203231729567051, 0.02052745781838894, -0.011581413447856903, 0.007072865031659603, -0.022258533164858818, -0.0004404392675496638, -0.009721152484416962, -0.0042049637995660305, 0.04443955421447754, -0.0006112053524702787, 0.003965971991419792, 0.024906819686293602, 0.0017633718671277165, -0.007169753778 ...
# MATCH (fl:FaultLocation)-[:HAS_FAULT]->(fs:FaultSymptom)-[:CAUSED_BY]->(fr:FaultReason)
# WHERE fl.name = 'Bron' AND fs.description CONTAINS 'beperkt tot 24mA'
# RETURN fr

# %% [markdown]
# THIS IS THE REAL RETRIEVER (HYBRID + TEXT TO CYPHER (GRAPH TRAVERSAL))

# %% [markdown]
# I added fulltext-index on Neo4J Aura:
#
# CREATE FULLTEXT INDEX `fulltext-index`
# FOR (n:FaultLocation|FaultSymptom|FaultReason|FaultMeasure)
# ON EACH [n.name, n.description]

# %%
# Setting up HybridCypherRetriever

from neo4j_graphrag.retrievers import HybridCypherRetriever

cypher_traversal_query = """
WITH node, score
OPTIONAL MATCH (node)<-[:CAUSED_BY]-(sym_from_reason:FaultSymptom)
OPTIONAL MATCH (node)<-[:MITIGATED_BY]-(sym_from_measure:FaultSymptom)
OPTIONAL MATCH (node)-[:HAS_FAULT]->(sym_from_loc:FaultSymptom)
WITH node, score,
    CASE 
       WHEN sym_from_reason IS NOT NULL THEN sym_from_reason
       WHEN sym_from_measure IS NOT NULL THEN sym_from_measure
       WHEN sym_from_loc IS NOT NULL THEN sym_from_loc
       WHEN node:FaultSymptom THEN node
       ELSE NULL 
    END AS symptom,
    node:FaultLocation AS isLocation
OPTIONAL MATCH (location:FaultLocation)-[:HAS_FAULT]->(symptom)
OPTIONAL MATCH (symptom)-[:CAUSED_BY]->(reason:FaultReason)
OPTIONAL MATCH (symptom)-[:MITIGATED_BY]->(measure:FaultMeasure)
WITH coalesce(location, CASE WHEN isLocation THEN node END) AS location,
     symptom, reason, measure, node, score
RETURN 
  coalesce(location.name, '') + ": " + coalesce(symptom.description, '') 
    + CASE WHEN reason IS NOT NULL THEN " Cause: " + reason.name ELSE "" END 
    + CASE WHEN measure IS NOT NULL THEN " Measure: " + measure.description ELSE "" END 
  AS text,
  score,
  {
    location: location.name, 
    symptom: symptom.description, 
    reason: reason.name, 
    measure: measure.description,
    location_id: elementId(location),
    symptom_id: elementId(symptom),
    reason_id: elementId(reason),
    measure_id: elementId(measure)
  } AS metadata
"""

retriever = HybridCypherRetriever(
    driver,
    vector_index_name="content_index",
    fulltext_index_name="fulltext-index",
    retrieval_query=cypher_traversal_query,
    embedder=embedder
)

# %%
# Language Detection

from langdetect import detect

def detect_language(text: str) -> str:
    try:
        lang_code = detect(text)
    except Exception:
        lang_code = "en"
    return "nl" if lang_code.startswith("nl") else "en"

# %% [markdown]
# the OpenAI embedding model can handle Dutch queries to some extent in the vector space. No need to translate the query since ADA is multilingual embeddings

# %%
from dotenv import load_dotenv
import os
import openai

# Load environment variables from .env file
load_dotenv()

# Read API key from environment
openai_api_key = os.getenv("OPENAI_API_KEY")

# Assign to OpenAI library
openai.api_key = openai_api_key

# Choose the model
OPENAI_MODEL = "gpt-3.5-turbo"

# %%
from openai import OpenAI

# Instantiate OpenAI client (will read OPENAI_API_KEY from env automatically)
client = OpenAI()

def generate_answer(user_query: str, graph_context: str, user_lang: str) -> str:

    #prompt for retriever behaviour and language (tuple)
    system_msg = (
        "You are an industrial maintenance assistant. "
        "If the user speaks Dutch, answer in Dutch; if English, answer in English. "
        "Use the provided graph context for factual information, and translate it if needed. "
        "Clearly mark any information taken from the graph context as [Graph], and any additional info from your general knowledge as [LLM]."
    )

    #user message with question and context
    user_msg = (
        f"**Graph context**:\n{graph_context}\n\n"
        f"**Question**:\n{user_query}\n\n"
        "**Answer** (please respond in the user's language and indicate [Graph] or [LLM] sources):"
    )

    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user", "content": user_msg}
    ]

    # New SDK call using OpenAI client
    response = client.chat.completions.create(
        model=OPENAI_MODEL,
        messages=messages
    )

    answer = response.choices[0].message.content
    return answer

# %%
#Testing the logic

question = "Ik heb een probleem met de neutralizer. Hij produceert geen emissie. Hoe komt dat en wat is de oplossing?"

lang = detect_language(question)
print(f"[DEBUG] Detected language: {lang}")

retriever_result = retriever.search(query_text=question, top_k=5)

# Extract graph context into a readable string
context_chunks = []
for item in retriever_result.items:
    meta = item.metadata
    if not meta:
        continue

    snippet = ""
    if "symptom" in meta:
        snippet += f"Symptom: {meta['symptom']}\n"
    if "reason" in meta and meta['reason']:
        snippet += f"Reason: {meta['reason']}\n"
    if "measure" in meta and meta['measure']:
        snippet += f"Measure: {meta['measure']}\n"
    if "location" in meta and meta['location']:
        snippet = f"Location: {meta['location']}\n" + snippet

    context_chunks.append(snippet)

# Combine all context snippets
graph_context = "\n\n".join(context_chunks)
if not graph_context:
    graph_context = "(No graph context found — LLM will use general knowledge)"

print("\n==== Retrieved Graph Context ====")
print(graph_context)

# === Step 5: Generate the LLM answer ===
answer = generate_answer(user_query=question, graph_context=graph_context, user_lang=lang)

print("\n==== LLM Answer ====")
print(answer)
# Out:
# [DEBUG] Detected language: nl
#
# ==== Retrieved Graph Context ====
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: Neutralizer schoongemaakt / gerepareerd
#
#
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: keramische binnenplaat vervangen
#
#
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: binnenkant en diafragma gestraald
#
#
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: Bron schoongemaakt
#
#
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: keramische buizen gestraald
#
#
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: schone kwartscilinder erin
#
#
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: Dekplaat buitenkant bron gestraald/schoongemaakt
#
#
# Location: Neutralizer
# Symptom: Neutralizer starte wel gelijk maar geen emissie
# Measure: blisters verwijdert
#
#
# Location: Compressor
# Symptom: Tijdens regenereren valt de compressor uit
# Reason: probleem met de koeling
# Measure: Koelslangen omgewisseld en de compressor werkt weer
#
#
# Location: Compressor
# Symptom: inlaat temp. 34 graden celcius
# Reason: probleem met de koeling
# Measure: Koelslangen omgewisseld en de compressor werkt weer
#
#
# Location: Compressor
# Symptom: uitgangs temp. ruim onder 20 graden celcius
# Reason: probleem met de koeling
# Measure: Koelslangen omgewisseld en de compressor werkt weer
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Inlaatgasklep blijft waarschijnlijk dichtzitten
# Measure: Hele gas-unit (twee kleppen met massaflowmeter uit ibm3 in ibm4 gezet)
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Gebroken al-oxide plaat in neutralizer
# Measure: Hele gas-unit (twee kleppen met massaflowmeter uit ibm3 in ibm4 gezet)
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Voedings-unit (deels) defect
# Measure: Hele gas-unit (twee kleppen met massaflowmeter uit ibm3 in ibm4 gezet)
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Inlaatgasklep blijft waarschijnlijk dichtzitten
# Measure: Al-oxide schijf vernieuwd
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Gebroken al-oxide plaat in neutralizer
# Measure: Al-oxide schijf vernieuwd
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Voedings-unit (deels) defect
# Measure: Al-oxide schijf vernieuwd
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Inlaatgasklep blijft waarschijnlijk dichtzitten
# Measure: Ion source controller isc 600 vervangen (komt uit ibm3)
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Gebroken al-oxide plaat in neutralizer
# Measure: Ion source controller isc 600 vervangen (komt uit ibm3)
#
#
# Location: Neutralizer
# Symptom: Neutralizer start niet goed op
# Reason: Voedings-unit (deels) defect
# Measure: Ion source controller isc 600 vervangen (komt uit ibm3)
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Glassmann voeding kapot
# Measure: Nieuwe Glassmann voeding aangesloten
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Zekering kapot
# Measure: Nieuwe Glassmann voeding aangesloten
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Glassmann voeding kapot
# Measure: Nieuwe zekering 1A T erin
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Zekering kapot
# Measure: Nieuwe zekering 1A T erin
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Glassmann voeding kapot
# Measure: Voor de zekerheid diafragma, neutralizer iets gestraald (Oxides eraf)
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Zekering kapot
# Measure: Voor de zekerheid diafragma, neutralizer iets gestraald (Oxides eraf)
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Glassmann voeding kapot
# Measure: Clive had bron en neutralizer al schoongemaakt
#
#
# Location: Neutralizer
# Symptom: Neutralizer werkt niet
# Reason: Zekering kapot
# Measure: Clive had bron en neutralizer al schoongemaakt
#
#
# Location: Ionbeam-controller
# Symptom: Neutralizer wilde niet starten
# Reason: Relais van print kan ratelen als Glasmann voeding geen 220V heeft
# Measure: Kabel naar print getest. Ok
#
#
# Location: Ionbeam-controller
# Symptom: Neutralizer wilde niet starten
# Reason: Er komt pas spanning van Glasmann voeding, als deze vrijgegeven wordt door de ibm controller
# Measure: Kabel naar print getest. Ok
#
#
# Location: Ionbeam-controller
# Symptom: Neutralizer wilde niet starten
# Reason: Dit gebeurt pas, als de neutralizer wordt gestart nadat het Ar in de neutralizer stroomt
# Measure: Kabel naar print getest. Ok
#
#
# Location: Ionbeam-controller
# Symptom: Neutralizer wilde niet starten
# Reason: Relais van print kan ratelen als Glasmann voeding geen 220V heeft
# Measure: Glasmann voedingen getest; nieuw = 1001V / oud = 996V
#
#
# Location: Ionbeam-controller
# Symptom: Neutralizer wilde niet starten
# Reason: Er komt pas spanning van Glasmann voeding, als deze vrijgegeven wordt door de ibm controller
# Measure: Glasmann voedingen getest; nieuw = 1001V / oud = 996V
#
#
# Location: Ionbeam-controller
# Symptom: Neutralizer wilde niet starten
# Reason: Dit gebeurt pas, als de neutralizer wordt gestart nadat het Ar in de neutralizer stroomt
# Measure: Glasmann voedingen getest; nieuw = 1001V / oud = 996V
#
#
# ==== LLM Answer ====
# Je neutralizer start wel gelijk, maar er is geen emissie. Dit kan veroorzaakt worden door verschillende redenen, zoals een vuile neutralizer, een defecte keramische binnenplaat, of een verstopte inlaatgasklep. Om dit op te lossen, kunnen maatregelen zoals het schoonmaken/repareren van de neutralizer, het vervangen van keramische onderdelen, stralen van de binnenkant en diafragma, of het vervangen van onderdelen nodig zijn. Verder kan het vervangen of repareren van de Glassmann voeding of zekeringen nodig zijn. Het is belangrijk om eerst de specifieke oorzaak van het probleem te identificeren voordat de juiste maatregel wordt genomen. [Graph]

# %%
#Testing the logic

question = "Ik heb een probleem in de compressor gevonden, namelijk een lekkage van helium in de warmtewisselaar. Wat is de oorzaak en wat is de oplossing?"

lang = detect_language(question)
print(f"[DEBUG] Detected language: {lang}")

retriever_result = retriever.search(query_text=question, top_k=5)

# Extract graph context into a readable string
context_chunks = []
for item in retriever_result.items:
    meta = item.metadata
    if not meta:
        continue

    snippet = ""
    if "symptom" in meta:
        snippet += f"Symptom: {meta['symptom']}\n"
    if "reason" in meta and meta['reason']:
        snippet += f"Reason: {meta['reason']}\n"
    if "measure" in meta and meta['measure']:
        snippet += f"Measure: {meta['measure']}\n"
    if "location" in meta and meta['location']:
        snippet = f"Location: {meta['location']}\n" + snippet

    context_chunks.append(snippet)

# Combine all context snippets
graph_context = "\n\n".join(context_chunks)
if not graph_context:
    graph_context = "(No graph context found — LLM will use general knowledge)"

print("\n==== Retrieved Graph Context ====")
print(graph_context)

# === Step 5: Generate the LLM answer ===
answer = generate_answer(user_query=question, graph_context=graph_context, user_lang=lang)

print("\n==== LLM Answer ====")
print(answer)
# Out:
# [DEBUG] Detected language: nl
#
# ==== Retrieved Graph Context ====
# Location: arm cover
# Symptom: Lekkage glycol in de cover van de arm
# Measure: Bestellen van keerringen en O-ringen via Oxford (ger-pt-office@oxinst.com)
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: He-lekkage aan de heatexchanger
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: He-lekkage aan de heatexchanger
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: He-lekkage aan de heatexchanger
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: He-lekkage aan de heatexchanger
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: He-lekkage aan de heatexchanger
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor afgevuld op 265 psi
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: He-lekkage aan de heatexchanger
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason: He-lekkage aan de heatexchanger
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
#
# Location: Compressor
# Symptom: He-lekkage in compressor
# Reason: naaldafsluiter niet naar behoren werkt
# Measure: Hulpstuk gemaakt om de naaldafsluiter te testen op lekkage, naaldafsluiter wat harder aangedraait
#
#
# Location: Compressor Cryopomp
# Symptom: Heeft He-verloren
# Reason: Warmtewisselaar is lek
# Measure: Compressor terug / volledig gereviseerd incl. nieuwe absorber
#
#
# Location: Compressor Cryopomp
# Symptom: druk op 0 tijdens regenereren
# Reason: Warmtewisselaar is lek
# Measure: Compressor terug / volledig gereviseerd incl. nieuwe absorber
#
#
# Location: Compressor Cryopomp
# Symptom: Vorige week 5 bar / nu 1 bar
# Reason: Warmtewisselaar is lek
# Measure: Compressor terug / volledig gereviseerd incl. nieuwe absorber
#
#
# ==== LLM Answer ====
# **Antwoord**:
# De oorzaak van de heliumlekkage in de warmtewisselaar kan liggen aan een lekkage bij de adsorberaansluiting of direct aan de heatexchanger zelf, zoals aangegeven in de [Grafiek]. De oplossing voor dit probleem kan zijn om de warmtewisselaar te vervangen en mogelijk ook nieuwe adsorbers te plaatsen en het geheel met helium bij te vullen, zoals beschreven in de [Grafiek].

# %%
#Testing the logic

from collections import defaultdict

question = "Ik heb een probleem in de compressor gevonden, namelijk een lekkage van helium in de warmtewisselaar. Wat is de oorzaak en wat is de oplossing?"

lang = detect_language(question)
print(f"[DEBUG] Detected language: {lang}")

retriever_result = retriever.search(query_text=question, top_k=5)

#Agregate all results
grouped = defaultdict(lambda: {"location": set(), "symptom": set(), "reason": set(), "measure": set()})

for item in retriever_result.items:
    meta = item.metadata or {}

    location = (meta.get("location") or "").strip()
    symptom = (meta.get("symptom") or "").strip()
    reason = (meta.get("reason") or "").strip()
    measure = (meta.get("measure") or "").strip()

    # Build a group key that combines fields that are the same
    key = (location, symptom, measure)  # fields you want to be the same across grouped items
    grouped[key]["location"].add(location)
    grouped[key]["symptom"].add(symptom)
    grouped[key]["reason"].add(reason)
    grouped[key]["measure"].add(measure)

# === Step 2: Build the context string ===
context_str = ""

def format_field(name, values):
    values = sorted(v for v in values if v)
    if not values:
        return ""
    if len(values) == 1:
        return f"{name}: {values[0]}\n"
    return f"{name}:\n" + "".join(f"- {v}\n" for v in values)

for entry in grouped.values():
    snippet = ""
    snippet += format_field("Location", entry["location"])
    snippet += format_field("Symptom", entry["symptom"])
    snippet += format_field("Reason", entry["reason"])
    snippet += format_field("Measure", entry["measure"])
    context_str += snippet + "\n"

# Use context_str in your prompt
graph_context = context_str.strip() if context_str.strip() else "(No graph context found — LLM will use general knowledge)"

print("\n==== Retrieved Graph Context ====")
print(graph_context)

# === Step 5: Generate the LLM answer ===
answer = generate_answer(user_query=question, graph_context=graph_context, user_lang=lang)

print("\n==== LLM Answer ====")
print(answer)
# Out:
# [DEBUG] Detected language: nl
#
# ==== Retrieved Graph Context ====
# Location: arm cover
# Symptom: Lekkage glycol in de cover van de arm
# Measure: Bestellen van keerringen en O-ringen via Oxford (ger-pt-office@oxinst.com)
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
# Location: Compressor
# Symptom: He-lekkage aan de heatexchanger
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
# Location: Compressor
# Symptom: Lekkage gevonden bij adsorber aansluiting
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
# Location: Compressor
# Symptom: Druk direct na aanzetten: 5,4 bar
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor afgevuld op 265 psi
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor naar VS: warmte wisselaar vervangen
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Alle kleppen, heatexchanger, condensator wordt vervangen
#
# Location: Compressor
# Symptom: Meter geeft druk aan retourkant aan. Hoe hoger de druk des te slechter de cryo
# Reason:
# - He-lekkage aan de heatexchanger
# - Lekkage bij adsorber aansluiting
# Measure: Compressor volledig gereviseerd | Adsorber vervangen, He bijgevuld
#
# Location: Compressor
# Symptom: He-lekkage in compressor
# Reason: naaldafsluiter niet naar behoren werkt
# Measure: Hulpstuk gemaakt om de naaldafsluiter te testen op lekkage, naaldafsluiter wat harder aangedraait
#
# Location: Compressor Cryopomp
# Symptom: Heeft He-verloren
# Reason: Warmtewisselaar is lek
# Measure: Compressor terug / volledig gereviseerd incl. nieuwe absorber
#
# Location: Compressor Cryopomp
# Symptom: druk op 0 tijdens regenereren
# Reason: Warmtewisselaar is lek
# Measure: Compressor terug / volledig gereviseerd incl. nieuwe absorber
#
# Location: Compressor Cryopomp
# Symptom: Vorige week 5 bar / nu 1 bar
# Reason: Warmtewisselaar is lek
# Measure: Compressor terug / volledig gereviseerd incl. nieuwe absorber
#
# ==== LLM Answer ====
# De oorzaak van de heliumlekkage in de warmtewisselaar kan te wijten zijn aan lekkage aan de heatexchanger en bij de adsorberaansluiting, zoals aangegeven in het [Grafiek]. De voorgestelde oplossingen kunnen zijn het vervangen van de warmtewisselaar, adsorber en het spoelen van Cryo en slangen met helium, evenals het vullen van de adsorber met actieve kool met helium-vulling. Deze maatregelen kunnen helpen het probleem van de heliumlekkage in de warmtewisselaar aan te pakken.

# %%
for item in retriever_result:
    print(item)
# Out:
# ('items', [RetrieverResultItem(content="<Record text='arm cover: Lekkage glycol in de cover van de arm Measure: Bestellen van keerringen en O-ringen via Oxford (ger-pt-office@oxinst.com)' score=1.0 metadata={'measure': 'Bestellen van keerringen en O-ringen via Oxford (ger-pt-office@oxinst.com)', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:316', 'reason': None, 'location': 'arm cover', 'reason_id': None, 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:315', 'symptom': 'Lekkage glycol in de cover van de arm', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:314'}>", metadata={'measure': 'Bestellen van keerringen en O-ringen via Oxford (ger-pt-office@oxinst.com)', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:316', 'reason': None, 'location': 'arm cover', 'reason_id': None, 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:315', 'symptom': 'Lekkage glycol in de cover van de arm', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:314'}), RetrieverResultItem(content="<Record text='Compressor: He-lekkage aan de heatexchanger Cause: Lekkage bij adsorber aansluiting Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)' score=1.0 metadata={'measure': 'Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:113', 'reason': 'Lekkage bij adsorber aansluiting', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:111', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:118', 'symptom': 'He-lekkage aan de heatexchanger', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}>", metadata={'measure': 'Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:113', 'reason': 'Lekkage bij adsorber aansluiting', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:111', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:118', 'symptom': 'He-lekkage aan de heatexchanger', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}), RetrieverResultItem(content="<Record text='Compressor: He-lekkage aan de heatexchanger Cause: He-lekkage aan de heatexchanger Measure: Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)' score=1.0 metadata={'measure': 'Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:113', 'reason': 'He-lekkage aan de heatexchanger', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:112', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:118', 'symptom': 'He-lekkage aan de heatexchanger', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}>", metadata={'measure': 'Nieuwe adsorber, Cryo en slangen gespoeld met He en nieuwe adsorber (actieve kool met He-vulling)', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:113', 'reason': 'He-lekkage aan de heatexchanger', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:112', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:118', 'symptom': 'He-lekkage aan de heatexchanger', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}), RetrieverResultItem(content="<Record text='Compressor: He-lekkage aan de heatexchanger Cause: Lekkage bij adsorber aansluiting Measure: Compressor afgevuld op 265 psi' score=1.0 metadata={'measure': 'Compressor afgevuld op 265 psi', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:114', 'reason': 'Lekkage bij adsorber aansluiting', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:111', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:118', 'symptom': 'He-lekkage aan de heatexchanger', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}>", metadat ...
# ('metadata', {'query_vector': [0.007460727822035551, -0.005468662828207016, -0.0062394775450229645, -0.03725288435816765, -0.01381757203489542, 0.011977766640484333, 0.011927013285458088, -0.008672461844980717, 0.0007577301585115492, 0.016634376719594002, 0.007581266574561596, 0.008253747597336769, 0.005256133619695902, -0.0003100706380791962, 0.006915130186825991, -0.019349675625562668, 0.040551844984292984, 0.006004743743687868, 0.021988844498991966, -0.025122858583927155, -0.0023631982039660215, -0.018461493775248528, -0.00425692880526185, -0.015568559058010578, 0.00021530479716602713, -0.00914192944765091, 0.029538391157984734, -0.02371445670723915, 0.0196668840944767, -0.012288630940020084, 0.010366351343691349, -0.012218845076858997, -0.025021351873874664, -0.009325909428298473, 0.0035051463637501, -0.002432983834296465, 0.029233871027827263, -0.003444876754656434, 0.004764461424201727, -0.01391907874494791, 0.008767623454332352, 0.01037903968244791, 0.018715260550379753, -0.0019460698822513223, -0.016964273527264595, 0.029538391157984734, 0.0021094318944960833, -0.004513867199420929, -0.006769214756786823, 0.012193468399345875, 0.008932571858167648, 0.005900065414607525, -0.03463909402489662, 0.00028489227406680584, 0.0048532793298363686, -0.0011126063764095306, -0.01739567704498768, -0.005614578258246183, -0.010360007174313068, -0.01985720917582512, -0.0034575650934129953, -0.012472610920667648, -0.03844558820128441, 0.004161766264587641, -0.004555104300379753, -0.0019873068667948246, -0.029081612825393677, 0.022572508081793785, -0.01848687045276165, -0.007739870343357325, 0.03255821019411087, 0.021798521280288696, 0.004812042694538832, 0.013678000308573246, 0.008628052659332752, 0.0007609022432006896, -0.002886591013520956, 0.0034670813474804163, -0.0004504350945353508, -0.0025360763538628817, 0.018118910491466522, 0.010099896229803562, -0.01956537738442421, 0.007714494131505489, 0.01592383161187172, 0.002742261625826359, 0.005744633264839649, 0.017281481996178627, -0.0356287807226181, -0.029056236147880554, -0.013043585233390331, 0.023435313254594803, 0.026011040434241295, 0.012643903493881226, -0.0018239448545500636, -0.002367956330999732, 0.004875483922660351, 0.01955268904566765, -0.007651052437722683, -0.012130026705563068, -0.022991221398115158, -0.02292777970433235, -0.02025054581463337, -0.02192540466785431, -0.010112584568560123, 0.006940506864339113, 0.02594759874045849, 0.010239467956125736, 0.01523866318166256, -0.02479296177625656, -0.01711653359234333, 0.04915452376008034, 0.033674780279397964, -0.01967957243323326, -0.04385080933570862, -0.003936548717319965, 0.02969065122306347, -0.01436316967010498, -0.026011040434241295, -0.0031244968995451927, 0.010156993754208088, 0.018448805436491966, -0.007390941958874464, -0.03509587049484253, 0.004396500065922737, -0.0015241835499182343, -0.0356287807226181, -0.028396442532539368, -0.012225189246237278, -0.013145091943442822, -0.006375877186655998, 0.03522275388240814, 0.02469145506620407, -0.0001241075515281409, -0.007612987421452999, 0.021874651312828064, -0.023041974753141403, 0.00391434459015727, 0.005170487333089113, -0.027127612382173538, 0.009262467734515667, 0.0157335065305233, -0.012631215155124664, -0.020022157579660416, 0.0018905585166066885, 0.010049143806099892, -0.00958602037280798, 0.001961930189281702, -0.011730344966053963, 0.011038831435143948, 0.009034078568220139, -0.0232069231569767, -0.0035971365869045258, -0.012377448379993439, 0.00044488394632935524, 0.015428988263010979, -0.02948763780295849, 0.008082455024123192, -0.025693831965327263, -0.014413923025131226, -0.005570169072598219, 0.008450415916740894, 0.03238057345151901, 0.00860902015119791, -0.022471001371741295, 0.023536819964647293, 0.0016875455621629953, -0.012022175826132298, 0.03522275388240814, 0.012865948490798473, 0.00025178369833156466, 0.024247365072369576, -0.013081650249660015, 0.01879139058291912, 0.00905311107635498, 0.024856403470039368, -0.015035649761557579, 0.00775 ...

# %%
#Testing the logic

question = "the circuit breaker in compressor suddenly trips to OFF, what does it mean, what the cause of it and what would be the solution"
lang = detect_language(question)
print(f"[DEBUG] Detected language: {lang}")

retriever_result = retriever.search(query_text=question, top_k=3)

# Extract graph context into a readable string
context_chunks = []
for item in retriever_result.items:
    meta = item.metadata
    if not meta:
        continue

    snippet = ""
    if "symptom" in meta:
        snippet += f"Symptom: {meta['symptom']}\n"
    if "reason" in meta and meta['reason']:
        snippet += f"Reason: {meta['reason']}\n"
    if "measure" in meta and meta['measure']:
        snippet += f"Measure: {meta['measure']}\n"
    if "location" in meta and meta['location']:
        snippet = f"Location: {meta['location']}\n" + snippet

    context_chunks.append(snippet)

# Combine all context snippets
graph_context = "\n\n".join(context_chunks)
if not graph_context:
    graph_context = "(No graph context found — LLM will use general knowledge)"

print("\n==== Retrieved Graph Context ====")
print(graph_context)

# === Step 5: Generate the LLM answer ===
answer = generate_answer(user_query=question, graph_context=graph_context, user_lang=lang)

print("\n==== LLM Answer ====")
print(answer)
# Out:
# [DEBUG] Detected language: en
#
# ==== Retrieved Graph Context ====
# Location: Compressor
# Symptom: System circuit breaker (CB1) trips immediately to the OFF (0) position when switched to the ON (1) position.
# Reason: Incorrect phasing of input power.
# Measure: Check phasing of input power. Refer to 'Phase Check' in 'Section 3 - Installation'.
#
#
# Location: Compressor
# Symptom: System circuit breaker (CB1) remains in the ON (1) position and the compressor stops after several minutes of operation and remains OFF (0).
# Reason: Thermal protective switches are open.
# Measure: Check for inadequate water cooling. Refer to Table 1-3.
#
#
# Location: Compressor
# Symptom: System circuit breaker (CB1) remains in the ON (1) position and the compressor stops after several minutes of operation and remains OFF (0).
# Reason: Very cold water has caused a restriction of oil flow through the oil injection orifice during start-up.
# Measure: Check for inadequate water cooling. Refer to Table 1-3.
#
#
# Location: Compressor
# Symptom: System circuit breaker (CB1) remains in the ON (1) position and the compressor stops after several minutes of operation and remains OFF (0).
# Reason: Thermal protective switches are open.
# Measure: Recheck for proper cooling water temperature. Refer to Table 1-3. Restart compressor repeatedly until continuous operation is achieved.
#
#
# Location: Compressor
# Symptom: System circuit breaker (CB1) remains in the ON (1) position and the compressor stops after several minutes of operation and remains OFF (0).
# Reason: Very cold water has caused a restriction of oil flow through the oil injection orifice during start-up.
# Measure: Recheck for proper cooling water temperature. Refer to Table 1-3. Restart compressor repeatedly until continuous operation is achieved.
#
#
# Location: Compressor
# Symptom: Control Circuit circuit breaker (CB2) trips when excessive current is being drawn by the cold head or 24 volt compressor control circuits.
# Reason: Damaged On-Board power cable, connectors, or drive motor.
# Measure: Check for compressor operation with cryopump cable disconnected from compressor. Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center if the compressor operates improperly.
#
#
# Location: Compressor
# Symptom: Control Circuit circuit breaker (CB2) trips when excessive current is being drawn by the cold head or 24 volt compressor control circuits.
# Reason: Damaged component in the compressor power or control circuit.
# Measure: Check for compressor operation with cryopump cable disconnected from compressor. Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center if the compressor operates improperly.
#
#
# Location: Compressor
# Symptom: Control Circuit circuit breaker (CB2) trips when excessive current is being drawn by the cold head or 24 volt compressor control circuits.
# Reason: Damaged On-Board power cable, connectors, or drive motor.
# Measure: Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center.
#
#
# Location: Compressor
# Symptom: Control Circuit circuit breaker (CB2) trips when excessive current is being drawn by the cold head or 24 volt compressor control circuits.
# Reason: Damaged component in the compressor power or control circuit.
# Measure: Refer to 'Appendix A: Customer Brooks Automation Technical Support Information' to contact the Customer Support Center.
#
#
# ==== LLM Answer ====
# **Antwoord**:
# Als de zekering in de compressor plotseling naar de UIT-positie springt, kan dit verschillende oorzaken hebben volgens de grafiek. Eén reden kan zijn dat er een verkeerde fase van de ingangsstroom is. Een andere mogelijkheid is dat de thermische beveiligingsschakelaars open zijn als gevolg van onvoldoende waterkoeling. Voor oplossingen worden verschillende maatregelen voorgesteld, zoals het controleren van de fase van de ingangsstroom of het controleren van de koelwaterkoeling, afhankelijk van de specifieke situatie in de compressor. [Graph]

# %%
# debugging code for HybridCypherRetriever

debug_query = "RETURN elementId(node) AS nodeId, labels(node) AS labels, score"

question = "Ik heb een probleem met de Neutralizer. Hij produceert geen emissie. Hoe komt dat en wat is de oplossing?"

debug_retriever = HybridCypherRetriever(
    driver, 
    vector_index_name="content_index",
    fulltext_index_name="fulltext-index",
    retrieval_query=debug_query, 
    embedder=embedder
)
debug_results = debug_retriever.search(query_text=question, top_k=5)
for item in debug_results:
    print(item)
# Out:
# ('items', [RetrieverResultItem(content="<Record nodeId='4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:407' labels=['FaultSymptom', 'TextChunk'] score=1.0>", metadata=None), RetrieverResultItem(content="<Record nodeId='4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:68' labels=['FaultReason', 'TextChunk'] score=1.0>", metadata=None), RetrieverResultItem(content="<Record nodeId='4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:429' labels=['FaultSymptom', 'TextChunk'] score=0.9946382868435546>", metadata=None), RetrieverResultItem(content="<Record nodeId='4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:329' labels=['FaultSymptom', 'TextChunk'] score=0.9945410956685133>", metadata=None), RetrieverResultItem(content="<Record nodeId='4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:122' labels=['FaultSymptom', 'TextChunk'] score=0.9901674927916545>", metadata=None)])
# ('metadata', {'query_vector': [0.005382144823670387, -0.02229837328195572, -0.011521253734827042, -0.00020608033810276538, -0.007223235908895731, 0.0015339753590524197, 0.009936760179698467, -0.013779317028820515, -0.030381212010979652, 0.016306808218359947, 0.015408714301884174, 0.009154136292636395, -0.01200878992676735, 0.010719384998083115, 0.0016951510915532708, -0.005208941176533699, 0.03158722445368767, -0.003890668274834752, 0.008114914409816265, 0.006710039917379618, -0.003958025481551886, 0.009968834929168224, 2.3605018213856965e-05, -0.012380857020616531, 0.00557459332048893, -0.008480566553771496, 0.02190064638853073, -0.02778957225382328, 0.01056542620062828, -0.0025194725021719933, 0.02927784062922001, -0.0019854276906698942, -0.0160886999219656, -0.004144059028476477, -0.0027584293857216835, 0.005330825224518776, 0.020643316209316254, 0.019437303766608238, -0.0015772762708365917, -0.0021249528508633375, 0.013118577189743519, -0.0036885973531752825, 0.019770881161093712, 0.0004883382353000343, -0.018654679879546165, 0.03682182356715202, -0.006806264165788889, 0.0074926638044416904, -0.017461499199271202, 0.0041793412528932095, -0.006511176470667124, 0.0066138156689703465, -0.008390757255256176, -0.026994118466973305, -0.0019373154500499368, -0.019334664568305016, -0.007396439556032419, 0.0014441660605370998, -0.0016293978551402688, -0.022144414484500885, -0.006190428510308266, -0.016653215512633324, -0.0480351597070694, -0.005869681015610695, -0.010212603956460953, -0.025646977126598358, -0.011726532131433487, 0.0038201038260012865, -0.027943531051278114, -0.011636722832918167, 0.014048744924366474, 0.0009053100948221982, -0.007877561263740063, -0.0004281980509404093, 0.02184932678937912, 0.0011755399173125625, 0.0068575837649405, -0.013792146928608418, -0.006501554045826197, -0.021656878292560577, 0.0358210913836956, 0.0037848216015845537, -0.03068912960588932, 0.006174391135573387, 0.025441698729991913, 0.025762446224689484, 0.007377194706350565, 0.021926306188106537, -0.022375352680683136, -0.009263190440833569, 0.0013311025686562061, 0.02701977826654911, 0.028636345639824867, 0.012502741068601608, -0.007402854505926371, -0.008339437656104565, 0.018513550981879234, 0.01780790649354458, -0.005561763420701027, -0.02506963163614273, -0.01696113310754299, -0.00703720236197114, -0.029431799426674843, -0.016743024811148643, -0.002886728383600712, 0.0035410535056144, 0.004820836242288351, 0.011848416179418564, 0.011110696941614151, -0.02211875468492508, 0.009006592445075512, 0.039644401520490646, 0.0260703656822443, -0.027302036061882973, -0.03464074060320854, -0.003749539377167821, 0.03684748336672783, -0.0033678498584777117, -0.014407982118427753, -0.00717191630974412, 0.011136356741189957, -0.00033698545303195715, 0.0004490466380957514, -0.025095291435718536, 0.016422277316451073, 0.007223235908895731, -0.023273445665836334, -0.02370966225862503, -0.024492286145687103, -0.011463519185781479, -0.00703720236197114, 0.02678884007036686, 0.013612528331577778, 0.008345852605998516, -0.014407982118427753, 0.017256220802664757, -0.0367191843688488, 0.005834398791193962, -0.002678242512047291, -0.003983685281127691, 0.012085769325494766, 0.013015937991440296, -0.0037463319022208452, -0.010822024196386337, 0.010533351451158524, 0.01685849390923977, -0.008377927355468273, -0.0006402924191206694, 0.007608132902532816, 0.019001087173819542, -0.005131961777806282, -0.018603360280394554, 0.008082839660346508, -0.020053138956427574, 0.010732214897871017, 0.010648820549249649, -0.034794699400663376, 0.02229837328195572, -0.016922643408179283, -0.007274555508047342, 0.0029653115198016167, -0.002395984483882785, 0.016896983608603477, 0.0030086124315857887, -0.005693269893527031, 0.016717365011572838, 0.012913297861814499, -0.009378659538924694, 0.022824399173259735, -0.02048935741186142, 0.010616745799779892, 0.035205256193876266, -0.0017512819031253457, 0.03967006132006645, -0.023632682859897614, 0.03612900897860527, -0.0159988906 ...

# %%
# debugging code for HybridCypherRetriever

debug_query= """
WITH node, score
// Identify the central FaultSymptom regardless of starting node type
OPTIONAL MATCH (node)<-[:CAUSED_BY]-(sym_from_reason:FaultSymptom)
OPTIONAL MATCH (node)<-[:MITIGATED_BY]-(sym_from_measure:FaultSymptom)
OPTIONAL MATCH (node)-[:HAS_FAULT]->(sym_from_loc:FaultSymptom)
WITH node, score,
    // Determine the symptom node (if node *is* a symptom or came via reason/measure)
     CASE 
       WHEN sym_from_reason IS NOT NULL THEN sym_from_reason
       WHEN sym_from_measure IS NOT NULL THEN sym_from_measure
       WHEN sym_from_loc IS NOT NULL THEN sym_from_loc
       WHEN node:FaultSymptom THEN node
       ELSE NULL 
     END AS symptom,
    // If a FaultLocation was the start and had no symptoms, treat it as symptom for traversal
     node:FaultLocation AS isLocation
// Traverse upward to location and outward to reason/measure from the identified symptom
OPTIONAL MATCH (location:FaultLocation)-[:HAS_FAULT]->(symptom)
OPTIONAL MATCH (symptom)-[:CAUSED_BY]->(reason:FaultReason)
OPTIONAL MATCH (symptom)-[:MITIGATED_BY]->(measure:FaultMeasure)

// Fallback: if the original node was a FaultLocation with no symptom, use it as location
WITH coalesce(location, CASE WHEN isLocation THEN node END) AS location,
     symptom, reason, measure, node, score
// Return the aggregated context (example: concatenate descriptions or return as fields)

RETURN 
  coalesce(location.name, '') + ": " + coalesce(symptom.description, '') 
    + CASE WHEN reason IS NOT NULL THEN " Cause: " + reason.name ELSE "" END 
    + CASE WHEN measure IS NOT NULL THEN " Measure: " + measure.description ELSE "" END 
  AS text,
  score,
  {
    location: location.name, 
    symptom: symptom.description, 
    reason: reason.name, 
    measure: measure.description,
    location_id: elementId(location),
    symptom_id: elementId(symptom),
    reason_id: elementId(reason),
    measure_id: elementId(measure)
  } AS metadata
"""

question = "Ik heb een probleem met de Neutralizer. Hij produceert geen emissie. Hoe komt dat en wat is de oplossing?"

debug_retriever = HybridCypherRetriever(
    driver, 
    vector_index_name="content_index",
    fulltext_index_name="fulltext-index",
    retrieval_query=debug_query, 
    embedder=embedder
)
debug_results = debug_retriever.search(query_text=question, top_k=3)
print(debug_results)
# Out:
# items=[RetrieverResultItem(content="<Record text='Compressor: Tijdens regenereren valt de compressor uit Cause: probleem met de koeling Measure: Koelslangen omgewisseld en de compressor werkt weer' score=1.0 metadata={'measure': 'Koelslangen omgewisseld en de compressor werkt weer', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:69', 'reason': 'probleem met de koeling', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:68', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:67', 'symptom': 'Tijdens regenereren valt de compressor uit', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}>", metadata={'measure': 'Koelslangen omgewisseld en de compressor werkt weer', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:69', 'reason': 'probleem met de koeling', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:68', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:67', 'symptom': 'Tijdens regenereren valt de compressor uit', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}), RetrieverResultItem(content="<Record text='Compressor: inlaat temp. 34 graden celcius Cause: probleem met de koeling Measure: Koelslangen omgewisseld en de compressor werkt weer' score=1.0 metadata={'measure': 'Koelslangen omgewisseld en de compressor werkt weer', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:69', 'reason': 'probleem met de koeling', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:68', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:70', 'symptom': 'inlaat temp. 34 graden celcius', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}>", metadata={'measure': 'Koelslangen omgewisseld en de compressor werkt weer', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:69', 'reason': 'probleem met de koeling', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:68', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:70', 'symptom': 'inlaat temp. 34 graden celcius', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}), RetrieverResultItem(content="<Record text='Compressor: uitgangs temp. ruim onder 20 graden celcius Cause: probleem met de koeling Measure: Koelslangen omgewisseld en de compressor werkt weer' score=1.0 metadata={'measure': 'Koelslangen omgewisseld en de compressor werkt weer', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:69', 'reason': 'probleem met de koeling', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:68', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:71', 'symptom': 'uitgangs temp. ruim onder 20 graden celcius', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}>", metadata={'measure': 'Koelslangen omgewisseld en de compressor werkt weer', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:69', 'reason': 'probleem met de koeling', 'location': 'Compressor', 'reason_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:68', 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:71', 'symptom': 'uitgangs temp. ruim onder 20 graden celcius', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:66'}), RetrieverResultItem(content="<Record text='Neutralizer: Neutralizer starte wel gelijk maar geen emissie Measure: Neutralizer schoongemaakt / gerepareerd' score=1.0 metadata={'measure': 'Neutralizer schoongemaakt / gerepareerd', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:408', 'reason': None, 'location': 'Neutralizer', 'reason_id': None, 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:407', 'symptom': 'Neutralizer starte wel gelijk maar geen emissie', 'location_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:48'}>", metadata={'measure': 'Neutralizer schoongemaakt / gerepareerd', 'measure_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:408', 'reason': None, 'location': 'Neutralizer', 'reason_id': None, 'symptom_id': '4:27c1505a-061e-4c53-a17f-9cc7dc4d5c84:407', 'symptom': 'Neutralizer starte wel  ...
